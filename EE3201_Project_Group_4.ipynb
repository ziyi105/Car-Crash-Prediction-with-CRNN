# %% [markdown]
# <a href="https://colab.research.google.com/github/ziyi105/Car-Crash-Prediction-with-CRNN/blob/main/EE3201_Project_Group_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import the Videos and Text File to Local Google Collab**

# %% [markdown]
# # **Preprocessing**

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/videos

# !mkdir -p /content/video_frames

# !unzip /content/drive/MyDrive/CarCrash/videos/Crash-1500.zip -d /content/videos/car_crash
# !unzip /content/drive/MyDrive/CarCrash/videos/Normal.zip -d /content/videos/normal
# !unzip /content/drive/MyDrive/full_dataset.zip -d /content/video_frames
# Out:
# Mounted at /content/drive
# Archive:  /content/drive/MyDrive/full_dataset.zip
#   inflating: /content/video_frames/normal_000940_frames.npz
#   inflating: /content/video_frames/normal_001065_frames.npz
#   inflating: /content/video_frames/crash_000139_frames.npz
#   inflating: /content/video_frames/normal_000656_frames.npz
#   inflating: /content/video_frames/normal_000268_frames.npz
#   inflating: /content/video_frames/crash_000049_frames.npz
#   inflating: /content/video_frames/normal_000446_frames.npz
#   inflating: /content/video_frames/normal_000249_frames.npz
#   inflating: /content/video_frames/normal_001449_frames.npz
#   inflating: /content/video_frames/normal_001468_frames.npz
#   inflating: /content/video_frames/normal_002368_frames.npz
#   inflating: /content/video_frames/normal_001018_frames.npz
#   inflating: /content/video_frames/normal_002804_frames.npz
#   inflating: /content/video_frames/normal_001588_frames.npz
#   inflating: /content/video_frames/normal_002667_frames.npz
#   inflating: /content/video_frames/normal_002026_frames.npz
#   inflating: /content/video_frames/crash_000881_frames.npz
#   inflating: /content/video_frames/normal_000933_frames.npz
#   inflating: /content/video_frames/crash_000001_frames.npz
#   inflating: /content/video_frames/normal_000753_frames.npz
#   inflating: /content/video_frames/normal_000224_frames.npz
#   inflating: /content/video_frames/normal_002506_frames.npz
#   inflating: /content/video_frames/normal_001824_frames.npz
#   inflating: /content/video_frames/normal_000597_frames.npz
#   inflating: /content/video_frames/normal_000957_frames.npz
#   inflating: /content/video_frames/normal_000561_frames.npz
#   inflating: /content/video_frames/normal_000454_frames.npz
#   inflating: /content/video_frames/normal_002055_frames.npz
#   inflating: /content/video_frames/normal_002472_frames.npz
#   inflating: /content/video_frames/normal_002681_frames.npz
#   inflating: /content/video_frames/normal_001320_frames.npz
#   inflating: /content/video_frames/normal_002622_frames.npz
#   inflating: /content/video_frames/normal_001451_frames.npz
#   inflating: /content/video_frames/normal_000977_frames.npz
#   inflating: /content/video_frames/normal_000493_frames.npz
#   inflating: /content/video_frames/normal_002731_frames.npz
#   inflating: /content/video_frames/normal_002518_frames.npz
#   inflating: /content/video_frames/crash_000298_frames.npz
#   inflating: /content/video_frames/normal_002823_frames.npz
#   inflating: /content/video_frames/crash_001044_frames.npz
#   inflating: /content/video_frames/normal_002672_frames.npz
#   inflating: /content/video_frames/normal_001048_frames.npz
#   inflating: /content/video_frames/normal_001631_frames.npz
#   inflating: /content/video_frames/normal_001933_frames.npz
#   inflating: /content/video_frames/normal_001173_frames.npz
#   inflating: /content/video_frames/normal_000052_frames.npz
#   inflating: /content/video_frames/crash_001497_frames.npz
#   inflating: /content/video_frames/crash_000088_frames.npz
#   inflating: /content/video_frames/crash_001452_frames.npz
#   inflating: /content/video_frames/normal_002415_frames.npz
#   inflating: /content/video_frames/normal_000901_frames.npz
#   inflating: /content/video_frames/normal_001353_frames.npz
#   inflating: /content/video_frames/normal_000614_frames.npz
#   inflating: /content/video_frames/normal_001774_frames.npz
#   inflating: /content/video_frames/normal_002353_frames.npz
#   inflating: /content/video_frames/normal_000818_frames.npz
#   inflating: /content/video_frames/crash_000827_frames.npz
#   inflating: /content/video_frames/normal_000606_frames.npz
#   inflating: /content/video_frames/normal_000628_frames.npz
#   inflating: /content/video_frames/normal_001281_frames.npz
#   inflating: /content/video_frames/normal_000388_frames.npz
#   inflating: /content/video_frames/normal_002807_frames.npz
#   inflating: /content/video_frames/crash_000005_frames.npz
#   inflating: /content/video_frames/normal_000726_frames.npz
#   inflating: /content/video_frames/crash_000994_frames.npz
#   inflating: /content/video_frames/normal_002512_frames.npz
#   inflating: /content/video_frames/normal_000367_frames.npz
#   inflating: /content/video_frames/normal_002316_frames.npz
#   inflating: /content/video_frames/crash_000323_frames.npz
#   inflating: /content/video_frames/normal_001259_frames.npz
#   inflating: /content/video_frames/normal_001788_frames.npz
#   inflating: /content/video_frames/normal_002859_frames.npz
#   inflating: /content/video_frames/crash_000777_frames.npz
#   inflating: /content/video_frames/normal_002531_frames.npz
#   inflating: /content/video_frames/normal_002359_frames.npz
#   inflating: /content/video_frames/crash_000321_frames.npz
#   inflating: /content/video_frames/crash_000552_frames.npz
#   inflating: /content/video_frames/normal_001094_frames.npz
#   inflating: /content/video_frames/normal_000088_frames.npz
#   inflating: /content/video_frames/normal_000699_frames.npz
#   inflating: /content/video_frames/normal_002824_frames.npz
#   inflating: /content/video_frames/normal_001163_frames.npz
#   inflating: /content/video_frames/crash_000704_frames.npz
#   inflating: /content/video_frames/normal_000809_frames.npz
#   inflating: /content/video_frames/normal_000279_frames.npz
#   inflating: /content/video_frames/normal_001481_frames.npz
#   inflating: /content/video_frames/normal_001188_frames.npz
#   inflating: /content/video_frames/normal_002278_frames.npz
#   inflating: /content/video_frames/crash_001298_frames.npz
#   inflating: /content/video_frames/normal_000273_frames.npz
#   inflating: /content/video_frames/normal_000490_frames.npz
#   inflating: /content/video_frames/crash_000043_frames.npz
#   inflating: /content/video_frames/crash_001156_frames.npz
#   inflating: /content/video_frames/normal_002138_frames.npz
#   inflating: /content/video_frames/normal_000318_frames.npz
#   inflating: /content/video_frames/crash_000029_frames.npz
#   inflating: /content/video_frames/normal_002570_frames.npz
#   inflating: /content/video_frames/normal_000157_frames.npz
#   inflating: /content/video_frames/crash_001213_frames.npz
#   inflating: /content/video_frames/normal_000677_frames.npz
#   inflating: /content/video_frames/normal_001329_frames.npz
#   inflating: /content/video_frames/normal_002275_frames.npz
#   inflating: /content/video_frames/crash_001192_frames.npz
#   inflating: /content/video_frames/normal_002730_frames.npz
#   inflating: /content/video_frames/normal_001726_frames.npz
#   inflating: /content/video_frames/normal_002785_frames.npz
#   inflating: /content/video_frames/normal_001189_frames.npz
#   inflating: /content/video_frames/normal_000502_frames.npz
#   inflating: /content/video_frames/crash_000281_frames.npz
#   inflating: /content/video_frames/crash_000852_frames.npz
#   inflating: /content/video_frames/crash_000099_frames.npz
#   inflating: /content/video_frames/normal_001827_frames.npz
#   inflating: /content/video_frames/normal_000503_frames.npz
#   inflating: /content/video_frames/normal_001976_frames.npz
#   inflating: /content/video_frames/normal_000800_frames.npz
#   inflating: /content/video_frames/crash_001461_frames.npz
#   inflating: /content/video_frames/normal_002648_frames.npz
#   inflating: /content/video_frames/normal_002717_frames.npz
#   inflating: /content/video_frames/normal_001108_frames.npz
#   inflating: /content/video_frames/normal_002327_frames.npz
#   inflating: /content/video_frames/normal_001067_frames.npz
#   inflating: /content/video_frames/crash_000106_frames.npz
#   inflating: /content/video_frames/normal_000445_frames.npz
#   inflating: /content/video_frames/crash_001353_frames.npz
#   inflating: /content/video_frames/normal_001738_frames.npz
#   inflating: /content/video_frames/normal_002659_frames.npz
#   inflating: /content/video_frames/crash_001101_frames.npz
#   inflating: /content/video_frames/normal_001135_frames.npz
#   inflating: /content/video_frames/normal_000676_frames.npz
#   inflating: /content/video_frames/normal_002726_frames.npz
#   inflating: /content/video_frames/crash_000222_frames.npz
#   inflating: /content/video_frames/normal_002203_frames.npz
#   inflating: /content/video_frames/normal_002805_frames.npz
#   inflating: /content/video_frames/normal_000903_frames.npz
#   inflating: /content/video_frames/crash_000718_frames.npz
#   inflating: /content/video_frames/crash_001405_frames.npz
#   inflating: /content/video_frames/normal_000434_frames.npz
#   inflating: /content/video_frames/normal_000706_frames.npz
#   inflating: /content/video_frames/normal_002300_frames.npz
#   inflating: /content/video_frames/normal_001638_frames.npz
#   inflating: /content/video_frames/crash_001324_frames.npz
#   inflating: /content/video_frames/crash_000507_frames.npz
#   inflating: /content/video_frames/normal_000064_frames.npz
#   inflating: /content/video_frames/normal_001523_frames.npz
#   inflating: /content/video_frames/normal_000337_frames.npz
#   inflating: /content/video_frames/normal_002241_frames.npz
#   inflating: /content/video_frames/normal_002993_frames.npz
#   inflating: /content/video_frames/normal_002579_frames.npz
#   inflating: /content/video_frames/normal_000687_frames.npz
#   inflating: /content/video_frames/normal_002935_frames.npz
#   inflating: /content/video_frames/normal_002036_frames.npz
#   inflating: /content/video_frames/normal_000904_frames.npz
#   inflating: /content/video_frames/normal_002249_frames.npz
#   inflating: /content/video_frames/crash_000186_frames.npz
#   inflating: /content/video_frames/normal_001918_frames.npz
#   inflating: /content/video_frames/normal_002904_frames.npz
#   inflating: /content/video_frames/normal_002034_frames.npz
#   inflating: /content/video_frames/normal_001848_frames.npz
#   inflating: /content/video_frames/normal_001347_frames.npz
#   inflating: /content/video_frames/normal_001939_frames.npz
#   inflating: /content/video_frames/normal_002881_frames.npz
#   inflating: /content/video_frames/normal_001324_frames.npz
#   inflating: /content/video_frames/crash_000711_frames.npz
#   inflating: /content/video_frames/normal_001511_frames.npz
#   inflating: /content/video_frames/normal_001393_frames.npz
#   inflating: /content/video_frames/normal_002135_frames.npz
#   inflating: /content/video_frames/normal_001002_frames.npz
#   inflating: /content/video_frames/normal_000851_frames.npz
#   inflating: /content/video_frames/normal_002100_frames.npz
#   inflating: /content/video_frames/normal_000016_frames.npz
#   inflating: /content/video_frames/normal_000660_frames.npz
#   inflating: /content/video_frames/normal_001644_frames.npz
#   inflating: /content/video_frames/normal_000986_frames.npz
#   inflating: /content/video_frames/normal_001304_frames.npz
#   inflating: /content/video_frames/normal_000911_frames.npz
#   inflating: /content/video_frames/normal_000894_frames.npz
#   inflating: /content/video_frames/normal_002581_frames.npz
#   inflating: /content/video_frames/normal_000059_frames.npz
#   inflating: /content/video_frames/normal_000945_frames.npz
#   inflating: /content/video_frames/normal_002150_frames.npz
#   inflating: /content/video_frames/normal_002199_frames.npz
#   inflating: /content/video_frames/normal_001990_frames.npz
#   inflating: /content/video_frames/normal_000822_frames.npz
#   inflating: /content/video_frames/normal_002709_frames.npz
#   inflating: /content/video_frames/crash_001422_frames.npz
#   inflating: /content/video_frames/crash_000180_frames.npz
#   inflating: /content/video_frames/normal_002649_frames.npz
#   inflating: /content/video_frames/normal_000512_frames.npz
#   inflating: /content/video_frames/normal_001498_frames.npz
#   inflating: /content/video_frames/crash_001199_frames.npz
#   inflating: /content/video_frames/crash_001475_frames.npz
#   inflating: /content/video_frames/normal_000141_frames.npz
#   inflating: /content/video_frames/normal_001853_frames.npz
#   inflating: /content/video_frames/normal_002365_frames.npz
#   inflating: /content/video_frames/crash_000751_frames.npz
#   inflating: /content/video_frames/crash_001463_frames.npz
#   inflating: /content/video_frames/normal_000443_frames.npz
#   inflating: /content/video_frames/normal_000122_frames.npz
#   inflating: /content/video_frames/normal_002850_frames.npz
#   inflating: /content/video_frames/normal_000581_frames.npz
#   inflating: /content/video_frames/normal_000035_frames.npz
#   inflating: /content/video_frames/normal_000086_frames.npz
#   inflating: /content/video_frames/normal_000583_frames.npz
#   inflating: /content/video_frames/crash_000813_frames.npz
#   inflating: /content/video_frames/normal_002419_frames.npz
#   inflating: /content/video_frames/normal_001772_frames.npz
#   inflating: /content/video_frames/normal_000789_frames.npz
#   inflating: /content/video_frames/normal_000226_frames.npz
#   inflating: /content/video_frames/crash_000525_frames.npz
#   inflating: /content/video_frames/normal_000886_frames.npz
#   inflating: /content/video_frames/normal_000473_frames.npz
#   inflating: /content/video_frames/normal_000757_frames.npz
#   inflating: /content/video_frames/normal_000228_frames.npz
#   inflating: /content/video_frames/normal_000594_frames.npz
#   inflating: /content/video_frames/normal_000044_frames.npz
#   inflating: /content/video_frames/normal_000023_frames.npz
#   inflating: /content/video_frames/normal_000242_frames.npz
#   inflating: /content/video_frames/normal_000216_frames.npz
#   inflating: /content/video_frames/normal_002995_frames.npz
#   inflating: /content/video_frames/normal_002669_frames.npz
#   inflating: /content/video_frames/normal_000331_frames.npz
#   inflating: /content/video_frames/normal_002653_frames.npz
#   inflating: /content/video_frames/normal_000049_frames.npz
#   inflating: /content/video_frames/normal_001874_frames.npz
#   inflating: /content/video_frames/normal_002233_frames.npz
#   inflating: /content/video_frames/crash_000364_frames.npz
#   inflating: /content/video_frames/crash_000801_frames.npz
#   inflating: /content/video_frames/crash_000233_frames.npz
#   inflating: /content/video_frames/normal_001388_frames.npz
#   inflating: /content/video_frames/normal_001170_frames.npz
#   inflating: /content/video_frames/normal_001486_frames.npz
#   inflating: /content/video_frames/normal_002237_frames.npz
#   inflating: /content/video_frames/normal_001646_frames.npz
#   inflating: /content/video_frames/normal_000311_frames.npz
#   inflating: /content/video_frames/normal_002884_frames.npz
#   inflating: /content/video_frames/normal_000011_frames.npz
#   inflating: /content/video_frames/crash_001061_frames.npz
#   inflating: /content/video_frames/normal_002916_frames.npz
#   inflating: /content/video_frames/normal_000341_frames.npz
#   inflating: /content/video_frames/crash_000301_frames.npz
#   inflating: /content/video_frames/normal_001350_frames.npz
#   inflating: /content/video_frames/normal_002650_frames.npz
#   inflating: /content/video_frames/normal_002991_frames.npz
#   inflating: /content/video_frames/crash_000068_frames.npz
#   inflating: /content/video_frames/normal_000325_frames.npz
#   inflating: /content/video_frames/normal_002496_frames.npz
#   inflating: /content/video_frames/normal_002544_frames.npz
#   inflating: /content/video_frames/crash_001352_frames.npz
#   inflating: /content/video_frames/normal_000665_frames.npz
#   inflating: /content/video_frames/normal_002919_frames.npz
#   inflating: /content/video_frames/crash_000681_frames.npz
#   inflating: /content/video_frames/normal_001964_frames.npz
#   inflating: /content/video_frames/normal_002136_frames.npz
#   inflating: /content/video_frames/crash_000727_frames.npz
#   inflating: /content/video_frames/normal_001459_frames.npz
#   inflating: /content/video_frames/normal_000825_frames.npz
#   inflating: /content/video_frames/normal_002497_frames.npz
#   inflating: /content/video_frames/normal_000555_frames.npz
#   inflating: /content/video_frames/normal_000895_frames.npz
#   inflating: /content/video_frames/normal_002462_frames.npz
#   inflating: /content/video_frames/normal_001759_frames.npz
#   inflating: /content/video_frames/normal_002178_frames.npz
#   inflating: /content/video_frames/normal_001659_frames.npz
#   inflating: /content/video_frames/crash_000310_frames.npz
#   inflating: /content/video_frames/normal_000858_frames.npz
#   inflating: /content/video_frames/normal_000805_frames.npz
#   inflating: /content/video_frames/normal_001569_frames.npz
#   inflating: /content/video_frames/crash_000227_frames.npz
#   inflating: /content/video_frames/crash_001084_frames.npz
#   inflating: /content/video_frames/normal_000470_frames.npz
#   inflating: /content/video_frames/normal_001472_frames.npz
#   inflating: /content/video_frames/crash_000698_frames.npz
#   inflating: /content/video_frames/crash_000189_frames.npz
#   inflating: /content/video_frames/crash_001362_frames.npz
#   inflating: /content/video_frames/normal_001288_frames.npz
#   inflating: /content/video_frames/normal_000371_frames.npz
#   inflating: /content/video_frames/normal_002315_frames.npz
#   inflating: /content/video_frames/crash_000594_frames.npz
#   inflating: /content/video_frames/normal_000161_frames.npz
#   inflating: /content/video_frames/crash_001036_frames.npz
#   inflating: /content/video_frames/normal_002971_frames.npz
#   inflating: /content/video_frames/normal_001439_frames.npz
#   inflating: /content/video_frames/crash_000340_frames.npz
#   inflating: /content/video_frames/crash_000512_frames.npz
#   inflating: /content/video_frames/normal_002003_frames.npz
#   inflating: /content/video_frames/crash_000873_frames.npz
#   inflating: /content/video_frames/normal_001457_frames.npz
#   inflating: /content/video_frames/normal_001309_frames.npz
#   inflating: /content/video_frames/normal_001150_frames.npz
#   inflating: /content/video_frames/normal_002425_frames.npz
#   inflating: /content/video_frames/normal_000711_frames.npz
#   inflating: /content/video_frames/normal_000979_frames.npz
#   inflating: /content/video_frames/normal_002469_frames.npz
#   inflating: /content/video_frames/normal_000641_frames.npz
#   inflating: /content/video_frames/crash_000828_frames.npz
#   inflating: /content/video_frames/normal_001149_frames.npz
#   inflating: /content/video_frames/normal_002252_frames.npz
#   inflating: /content/video_frames/normal_002069_frames.npz
#   inflating: /content/video_frames/normal_000557_frames.npz
#   inflating: /content/video_frames/crash_000630_frames.npz
#   inflating: /content/video_frames/normal_001998_frames.npz
#   inflating: /content/video_frames/normal_000764_frames.npz
#   inflating: /content/video_frames/crash_001139_frames.npz
#   inflating: /content/video_frames/normal_001898_frames.npz
#   inflating: /content/video_frames/normal_001027_frames.npz
#   inflating: /content/video_frames/crash_000489_frames.npz
#   inflating: /content/video_frames/normal_002325_frames.npz
#   inflating: /content/video_frames/crash_000937_frames.npz
#   inflating: /content/video_frames/normal_002780_frames.npz
#   inflating: /content/video_frames/normal_001264_frames.npz
#   inflating: /content/video_frames/normal_002523_frames.npz
#   inflating: /content/video_frames/crash_000530_frames.npz
#   inflating: /content/video_frames/normal_001782_frames.npz
#   inflating: /content/video_frames/normal_000186_frames.npz
#   inflating: /content/video_frames/normal_001434_frames.npz
#   inflating: /content/video_frames/normal_002401_frames.npz
#   inflating: /content/video_frames/normal_001755_frames.npz
#   inflating: /content/video_frames/crash_000977_frames.npz
#   inflating: /content/video_frames/normal_002546_frames.npz
#   inflating: /content/video_frames/normal_000477_frames.npz
#   inflating: /content/video_frames/crash_000706_frames.npz
#   inflating: /content/video_frames/normal_000427_frames.npz
#   inflating: /content/video_frames/normal_001146_frames.npz
#   inflating: /content/video_frames/normal_002728_frames.npz
#   inflating: /content/video_frames/normal_000604_frames.npz
#   inflating: /content/video_frames/normal_001947_frames.npz
#   inflating: /content/video_frames/normal_002056_frames.npz
#   inflating: /content/video_frames/normal_001721_frames.npz
#   inflating: /content/video_frames/normal_002065_frames.npz
#   inflating: /content/video_frames/normal_002355_frames.npz
#   inflating: /content/video_frames/normal_001894_frames.npz
#   inflating: /content/video_frames/normal_001266_frames.npz
#   inflating: /content/video_frames/normal_002324_frames.npz
#   inflating: /content/video_frames/normal_000405_frames.npz
#   inflating: /content/video_frames/normal_001962_frames.npz
#   inflating: /content/video_frames/normal_000684_frames.npz
#   inflating: /content/video_frames/normal_001358_frames.npz
#   inflating: /content/video_frames/normal_001551_frames.npz
#   inflating: /content/video_frames/normal_002445_frames.npz
#   inflating: /content/video_frames/crash_001455_frames.npz
#   inflating: /content/video_frames/normal_001361_frames.npz
#   inflating: /content/video_frames/crash_000176_frames.npz
#   inflating: /content/video_frames/normal_000985_frames.npz
#   inflating: /content/video_frames/normal_000032_frames.npz
#   inflating: /content/video_frames/normal_002013_frames.npz
#   inflating: /content/video_frames/normal_002302_frames.npz
#   inflating: /content/video_frames/normal_002631_frames.npz
#   inflating: /content/video_frames/crash_000563_frames.npz
#   inflating: /content/video_frames/normal_001110_frames.npz
#   inflating: /content/video_frames/normal_000272_frames.npz
#   inflating: /content/video_frames/normal_001930_frames.npz
#   inflating: /content/video_frames/normal_002687_frames.npz
#   inflating: /content/video_frames/normal_000041_frames.npz
#   inflating: /content/video_frames/normal_002924_frames.npz
#   inflating: /content/video_frames/normal_000845_frames.npz
#   inflating: /content/video_frames/normal_002318_frames.npz
#   inflating: /content/video_frames/crash_001173_frames.npz
#   inflating: /content/video_frames/normal_002580_frames.npz
#   inflating: /content/video_frames/normal_000811_frames.npz
#   inflating: /content/video_frames/crash_000435_frames.npz
#   inflating: /content/video_frames/normal_001289_frames.npz
#   inflating: /content/video_frames/normal_001294_frames.npz
#   inflating: /content/video_frames/normal_000907_frames.npz
#   inflating: /content/video_frames/normal_001423_frames.npz
#   inflating: /content/video_frames/normal_002851_frames.npz
#   inflating: /content/video_frames/normal_001095_frames.npz
#   inflating: /content/video_frames/normal_002009_frames.npz
#   inflating: /content/video_frames/normal_002964_frames.npz
#   inflating: /content/video_frames/normal_000254_frames.npz
#   inflating: /content/video_frames/crash_000085_frames.npz
#   inflating: /content/video_frames/normal_001697_frames.npz
#   inflating: /content/video_frames/normal_002798_frames.npz
#   inflating: /content/video_frames/normal_002791_frames.npz
#   inflating: /content/video_frames/normal_001389_frames.npz
#   inflating: /content/video_frames/normal_001409_frames.npz
#   inflating: /content/video_frames/normal_002839_frames.npz
#   inflating: /content/video_frames/normal_001179_frames.npz
#   inflating: /content/video_frames/normal_001191_frames.npz
#   inflating: /content/video_frames/normal_001033_frames.npz
#   inflating: /content/video_frames/normal_001180_frames.npz
#   inflating: /content/video_frames/normal_001546_frames.npz
#   inflating: /content/video_frames/normal_002548_frames.npz
#   inflating: /content/video_frames/crash_000768_frames.npz
#   inflating: /content/video_frames/normal_000923_frames.npz
#   inflating: /content/video_frames/normal_002757_frames.npz
#   inflating: /content/video_frames/crash_000116_frames.npz
#   inflating: /content/video_frames/normal_002221_frames.npz
#   inflating: /content/video_frames/normal_000974_frames.npz
#   inflating: /content/video_frames/normal_000020_frames.npz
#   inflating: /content/video_frames/normal_000935_frames.npz
#   inflating: /content/video_frames/normal_002877_frames.npz
#   inflating: /content/video_frames/normal_002187_frames.npz
#   inflating: /content/video_frames/crash_000112_frames.npz
#   inflating: /content/video_frames/normal_000540_frames.npz
#   inflating: /content/video_frames/crash_000399_frames.npz
#   inflating: /content/video_frames/normal_001958_frames.npz
#   inflating: /content/video_frames/normal_002070_frames.npz
#   inflating: /content/video_frames/normal_000397_frames.npz
#   inflating: /content/video_frames/normal_000751_frames.npz
#   inflating: /content/video_frames/normal_001906_frames.npz
#   inflating: /content/video_frames/normal_001602_frames.npz
#   inflating: /content/video_frames/normal_001295_frames.npz
#   inflating: /content/video_frames/normal_002240_frames.npz
#   inflating: /content/video_frames/normal_002643_frames.npz
#   inflating: /content/video_frames/normal_000760_frames.npz
#   inflating: /content/video_frames/normal_001484_frames.npz
#   inflating: /content/video_frames/normal_002609_frames.npz
#   inflating: /content/video_frames/normal_001665_frames.npz
#   inflating: /content/video_frames/normal_002162_frames.npz
#   inflating: /content/video_frames/normal_000197_frames.npz
#   inflating: /content/video_frames/normal_000382_frames.npz
#   inflating: /content/video_frames/normal_002598_frames.npz
#   inflating: /content/video_frames/normal_001714_frames.npz
#   inflating: /content/video_frames/normal_002371_frames.npz
#   inflating: /content/video_frames/normal_001946_frames.npz
#   inflating: /content/video_frames/normal_000755_frames.npz
#   inflating: /content/video_frames/normal_002589_frames.npz
#   inflating: /content/video_frames/normal_000040_frames.npz
#   inflating: /content/video_frames/normal_002697_frames.npz
#   inflating: /content/video_frames/normal_002200_frames.npz
#   inflating: /content/video_frames/normal_001485_frames.npz
#   inflating: /content/video_frames/normal_000651_frames.npz
#   inflating: /content/video_frames/normal_001596_frames.npz
#   inflating: /content/video_frames/crash_000548_frames.npz
#   inflating: /content/video_frames/crash_000949_frames.npz
#   inflating: /content/video_frames/normal_002751_frames.npz
#   inflating: /content/video_frames/normal_000225_frames.npz
#   inflating: /content/video_frames/normal_000468_frames.npz
#   inflating: /content/video_frames/normal_001255_frames.npz
#   inflating: /content/video_frames/normal_001609_frames.npz
#   inflating: /content/video_frames/normal_002164_frames.npz
#   inflating: /content/video_frames/normal_001765_frames.npz
#   inflating: /content/video_frames/normal_002450_frames.npz
#   inflating: /content/video_frames/normal_000420_frames.npz
#   inflating: /content/video_frames/normal_001237_frames.npz
#   inflating: /content/video_frames/normal_002762_frames.npz
#   inflating: /content/video_frames/crash_000203_frames.npz
#   inflating: /content/video_frames/normal_002068_frames.npz
#   inflating: /content/video_frames/normal_000211_frames.npz
#   inflating: /content/video_frames/normal_002756_frames.npz
#   inflating: /content/video_frames/crash_000053_frames.npz
#   inflating: /content/video_frames/crash_001331_frames.npz
#   inflating: /content/video_frames/normal_000128_frames.npz
#   inflating: /content/video_frames/crash_000303_frames.npz
#   inflating: /content/video_frames/normal_002720_frames.npz
#   inflating: /content/video_frames/normal_001942_frames.npz
#   inflating: /content/video_frames/normal_000564_frames.npz
#   inflating: /content/video_frames/crash_001357_frames.npz
#   inflating: /content/video_frames/normal_002739_frames.npz
#   inflating: /content/video_frames/normal_002812_frames.npz
#   inflating: /content/video_frames/normal_002080_frames.npz
#   inflating: /content/video_frames/normal_001363_frames.npz
#   inflating: /content/video_frames/crash_000585_frames.npz
#   inflating: /content/video_frames/normal_000847_frames.npz
#   inflating: /content/video_frames/normal_000155_frames.npz
#   inflating: /content/video_frames/normal_001957_frames.npz
#   inflating: /content/video_frames/crash_000249_frames.npz
#   inflating: /content/video_frames/normal_000014_frames.npz
#   inflating: /content/video_frames/normal_001326_frames.npz
#   inflating: /content/video_frames/normal_002996_frames.npz
#   inflating: /content/video_frames/normal_000869_frames.npz
#   inflating: /content/video_frames/normal_001430_frames.npz
#   inflating: /content/video_frames/normal_002410_frames.npz
#   inflating: /content/video_frames/normal_001940_frames.npz
#   inflating: /content/video_frames/normal_002113_frames.npz
#   inflating: /content/video_frames/crash_001255_frames.npz
#   inflating: /content/video_frames/normal_001091_frames.npz
#   inflating: /content/video_frames/normal_002436_frames.npz
#   inflating: /content/video_frames/normal_001156_frames.npz
#   inflating: /content/video_frames/normal_001473_frames.npz
#   inflating: /content/video_frames/normal_001767_frames.npz
#   inflating: /content/video_frames/normal_001789_frames.npz
#   inflating: /content/video_frames/crash_000315_frames.npz
#   inflating: /content/video_frames/normal_002942_frames.npz
#   inflating: /content/video_frames/normal_002597_frames.npz
#   inflating: /content/video_frames/normal_002395_frames.npz
#   inflating: /content/video_frames/crash_000150_frames.npz
#   inflating: /content/video_frames/normal_002424_frames.npz
#   inflating: /content/video_frames/normal_002676_frames.npz
#   inflating: /content/video_frames/normal_001492_frames.npz
#   inflating: /content/video_frames/normal_000255_frames.npz
#   inflating: /content/video_frames/normal_000535_frames.npz
#   inflating: /content/video_frames/crash_000169_frames.npz
#   inflating: /content/video_frames/normal_000139_frames.npz
#   inflating: /content/video_frames/normal_002743_frames.npz
#   inflating: /content/video_frames/crash_000707_frames.npz
#   inflating: /content/video_frames/normal_001794_frames.npz
#   inflating: /content/video_frames/normal_002741_frames.npz
#   inflating: /content/video_frames/crash_001163_frames.npz
#   inflating: /content/video_frames/normal_001364_frames.npz
#   inflating: /content/video_frames/normal_002678_frames.npz
#   inflating: /content/video_frames/normal_000609_frames.npz
#   inflating: /content/video_frames/normal_001403_frames.npz
#   inflating: /content/video_frames/normal_001398_frames.npz
#   inflating: /content/video_frames/normal_001015_frames.npz
#   inflating: /content/video_frames/normal_002181_frames.npz
#   inflating: /content/video_frames/normal_001579_frames.npz
#   inflating: /content/video_frames/crash_001333_frames.npz
#   inflating: /content/video_frames/normal_000143_frames.npz
#   inflating: /content/video_frames/normal_000431_frames.npz
#   inflating: /content/video_frames/normal_002192_frames.npz
#   inflating: /content/video_frames/normal_000453_frames.npz
#   inflating: /content/video_frames/normal_001121_frames.npz
#   inflating: /content/video_frames/normal_002946_frames.npz
#   inflating: /content/video_frames/crash_001265_frames.npz
#   inflating: /content/video_frames/normal_000662_frames.npz
#   inflating: /content/video_frames/normal_001200_frames.npz
#   inflating: /content/video_frames/normal_001690_frames.npz
#   inflating: /content/video_frames/normal_002239_frames.npz
#   inflating: /content/video_frames/crash_000028_frames.npz
#   inflating: /content/video_frames/normal_001333_frames.npz
#   inflating: /content/video_frames/normal_000568_frames.npz
#   inflating: /content/video_frames/crash_000204_frames.npz
#   inflating: /content/video_frames/normal_001192_frames.npz
#   inflating: /content/video_frames/normal_000336_frames.npz
#   inflating: /content/video_frames/normal_002074_frames.npz
#   inflating: /content/video_frames/normal_000605_frames.npz
#   inflating: /content/video_frames/normal_001510_frames.npz
#   inflating: /content/video_frames/normal_002489_frames.npz
#   inflating: /content/video_frames/normal_002930_frames.npz
#   inflating: /content/video_frames/normal_002813_frames.npz
#   inflating: /content/video_frames/normal_001624_frames.npz
#   inflating: /content/video_frames/crash_000107_frames.npz
#   inflating: /content/video_frames/normal_000582_frames.npz
#   inflating: /content/video_frames/normal_002499_frames.npz
#   inflating: /content/video_frames/crash_000214_frames.npz
#   inflating: /content/video_frames/normal_002773_frames.npz
#   inflating: /content/video_frames/normal_000972_frames.npz
#   inflating: /content/video_frames/crash_000541_frames.npz
#   inflating: /content/video_frames/normal_001115_frames.npz
#   inflating: /content/video_frames/normal_000240_frames.npz
#   inflating: /content/video_frames/normal_001014_frames.npz
#   inflating: /content/video_frames/normal_001521_frames.npz
#   inflating: /content/video_frames/normal_000374_frames.npz
#   inflating: /content/video_frames/normal_000395_frames.npz
#   inflating: /content/video_frames/normal_001280_frames.npz
#   inflating: /content/video_frames/normal_000528_frames.npz
#   inflating: /content/video_frames/normal_000198_frames.npz
#   inflating: /content/video_frames/crash_000792_frames.npz
#   inflating: /content/video_frames/normal_001828_frames.npz
#   inflating: /content/video_frames/crash_001400_frames.npz
#   inflating: /content/video_frames/crash_001048_frames.npz
#   inflating: /content/video_frames/crash_000446_frames.npz
#   inflating: /content/video_frames/crash_000004_frames.npz
#   inflating: /content/video_frames/normal_001643_frames.npz
#   inflating: /content/video_frames/normal_002273_frames.npz
#   inflating: /content/video_frames/normal_002867_frames.npz
#   inflating: /content/video_frames/normal_002366_frames.npz
#   inflating: /content/video_frames/normal_000013_frames.npz
#   inflating: /content/video_frames/normal_001186_frames.npz
#   inflating: /content/video_frames/normal_000103_frames.npz
#   inflating: /content/video_frames/normal_001041_frames.npz
#   inflating: /content/video_frames/normal_001904_frames.npz
#   inflating: /content/video_frames/normal_002875_frames.npz
#   inflating: /content/video_frames/normal_002777_frames.npz
#   inflating: /content/video_frames/normal_002433_frames.npz
#   inflating: /content/video_frames/normal_002633_frames.npz
#   inflating: /content/video_frames/normal_002466_frames.npz
#   inflating: /content/video_frames/normal_002711_frames.npz
#   inflating: /content/video_frames/normal_000283_frames.npz
#   inflating: /content/video_frames/normal_001081_frames.npz
#   inflating: /content/video_frames/normal_002416_frames.npz
#   inflating: /content/video_frames/normal_000717_frames.npz
#   inflating: /content/video_frames/normal_002690_frames.npz
#   inflating: /content/video_frames/normal_000667_frames.npz
#   inflating: /content/video_frames/normal_001488_frames.npz
#   inflating: /content/video_frames/normal_000530_frames.npz
#   inflating: /content/video_frames/normal_002430_frames.npz
#   inflating: /content/video_frames/normal_002774_frames.npz
#   inflating: /content/video_frames/crash_000810_frames.npz
#   inflating: /content/video_frames/normal_002912_frames.npz
#   inflating: /content/video_frames/normal_001390_frames.npz
#   inflating: /content/video_frames/normal_001994_frames.npz
#   inflating: /content/video_frames/normal_002098_frames.npz
#   inflating: /content/video_frames/normal_000297_frames.npz
#   inflating: /content/video_frames/normal_000196_frames.npz
#   inflating: /content/video_frames/crash_000319_frames.npz
#   inflating: /content/video_frames/crash_001046_frames.npz
#   inflating: /content/video_frames/normal_001548_frames.npz
#   inflating: /content/video_frames/normal_001655_frames.npz
#   inflating: /content/video_frames/normal_000306_frames.npz
#   inflating: /content/video_frames/normal_000625_frames.npz
#   inflating: /content/video_frames/normal_001187_frames.npz
#   inflating: /content/video_frames/normal_001590_frames.npz
#   inflating: /content/video_frames/normal_000121_frames.npz
#   inflating: /content/video_frames/normal_001629_frames.npz
#   inflating: /content/video_frames/normal_002025_frames.npz
#   inflating: /content/video_frames/normal_000504_frames.npz
#   inflating: /content/video_frames/normal_001234_frames.npz
#   inflating: /content/video_frames/normal_001497_frames.npz
#   inflating: /content/video_frames/normal_002414_frames.npz
#   inflating: /content/video_frames/normal_001610_frames.npz
#   inflating: /content/video_frames/normal_000219_frames.npz
#   inflating: /content/video_frames/crash_001214_frames.npz
#   inflating: /content/video_frames/normal_000814_frames.npz
#   inflating: /content/video_frames/crash_000014_frames.npz
#   inflating: /content/video_frames/normal_000350_frames.npz
#   inflating: /content/video_frames/crash_000699_frames.npz
#   inflating: /content/video_frames/normal_000416_frames.npz
#   inflating: /content/video_frames/normal_000486_frames.npz
#   inflating: /content/video_frames/normal_001469_frames.npz
#   inflating: /content/video_frames/normal_000175_frames.npz
#   inflating: /content/video_frames/normal_001117_frames.npz
#   inflating: /content/video_frames/crash_000570_frames.npz
#   inflating: /content/video_frames/normal_002786_frames.npz
#   inflating: /content/video_frames/crash_001364_frames.npz
#   inflating: /content/video_frames/normal_000937_frames.npz
#   inflating: /content/video_frames/normal_000343_frames.npz
#   inflating: /content/video_frames/normal_001330_frames.npz
#   inflating: /content/video_frames/normal_001608_frames.npz
#   inflating: /content/video_frames/normal_000591_frames.npz
#   inflating: /content/video_frames/normal_001902_frames.npz
#   inflating: /content/video_frames/normal_000039_frames.npz
#   inflating: /content/video_frames/normal_001505_frames.npz
#   inflating: /content/video_frames/normal_000831_frames.npz
#   inflating: /content/video_frames/normal_001040_frames.npz
#   inflating: /content/video_frames/normal_001044_frames.npz
#   inflating: /content/video_frames/normal_002251_frames.npz
#   inflating: /content/video_frames/normal_001713_frames.npz
#   inflating: /content/video_frames/normal_000438_frames.npz
#   inflating: /content/video_frames/normal_000422_frames.npz
#   inflating: /content/video_frames/normal_000494_frames.npz
#   inflating: /content/video_frames/normal_001447_frames.npz
#   inflating: /content/video_frames/normal_001075_frames.npz
#   inflating: /content/video_frames/normal_002447_frames.npz
#   inflating: /content/video_frames/normal_002453_frames.npz
#   inflating: /content/video_frames/normal_001307_frames.npz
#   inflating: /content/video_frames/normal_001019_frames.npz
#   inflating: /content/video_frames/normal_001219_frames.npz
#   inflating: /content/video_frames/crash_001147_frames.npz
#   inflating: /content/video_frames/normal_000600_frames.npz
#   inflating: /content/video_frames/normal_001777_frames.npz
#   inflating: /content/video_frames/normal_001876_frames.npz
#   inflating: /content/video_frames/normal_001817_frames.npz
#   inflating: /content/video_frames/normal_000638_frames.npz
#   inflating: /content/video_frames/crash_001280_frames.npz
#   inflating: /content/video_frames/normal_002077_frames.npz
#   inflating: /content/video_frames/normal_001063_frames.npz
#   inflating: /content/video_frames/normal_001151_frames.npz
#   inflating: /content/video_frames/normal_000257_frames.npz
#   inflating: /content/video_frames/normal_000801_frames.npz
#   inflating: /content/video_frames/normal_002722_frames.npz
#   inflating: /content/video_frames/normal_001595_frames.npz
#   inflating: /content/video_frames/normal_001883_frames.npz
#   inflating: /content/video_frames/normal_001045_frames.npz
#   inflating: /content/video_frames/crash_001479_frames.npz
#   inflating: /content/video_frames/normal_001663_frames.npz
#   inflating: /content/video_frames/normal_000369_frames.npz
#   inflating: /content/video_frames/normal_001811_frames.npz
#   inflating: /content/video_frames/normal_000291_frames.npz
#   inflating: /content/video_frames/normal_001206_frames.npz
#   inflating: /content/video_frames/crash_000010_frames.npz
#   inflating: /content/video_frames/crash_000651_frames.npz
#   inflating: /content/video_frames/crash_001201_frames.npz
#   inflating: /content/video_frames/normal_001368_frames.npz
#   inflating: /content/video_frames/normal_002736_frames.npz
#   inflating: /content/video_frames/crash_001021_frames.npz
#   inflating: /content/video_frames/normal_002994_frames.npz
#   inflating: /content/video_frames/normal_000976_frames.npz
#   inflating: /content/video_frames/crash_000433_frames.npz
#   inflating: /content/video_frames/normal_000209_frames.npz
#   inflating: /content/video_frames/crash_000397_frames.npz
#   inflating: /content/video_frames/normal_002354_frames.npz
#   inflating: /content/video_frames/normal_000507_frames.npz
#   inflating: /content/video_frames/normal_002343_frames.npz
#   inflating: /content/video_frames/normal_001605_frames.npz
#   inflating: /content/video_frames/normal_002400_frames.npz
#   inflating: /content/video_frames/normal_002871_frames.npz
#   inflating: /content/video_frames/normal_000003_frames.npz
#   inflating: /content/video_frames/crash_000653_frames.npz
#   inflating: /content/video_frames/crash_001476_frames.npz
#   inflating: /content/video_frames/normal_002921_frames.npz
#   inflating: /content/video_frames/normal_001342_frames.npz
#   inflating: /content/video_frames/normal_002558_frames.npz
#   inflating: /content/video_frames/crash_000059_frames.npz
#   inflating: /content/video_frames/normal_000152_frames.npz
#   inflating: /content/video_frames/normal_000657_frames.npz
#   inflating: /content/video_frames/normal_002448_frames.npz
#   inflating: /content/video_frames/normal_001581_frames.npz
#   inflating: /content/video_frames/normal_002498_frames.npz
#   inflating: /content/video_frames/crash_000471_frames.npz
#   inflating: /content/video_frames/normal_001520_frames.npz
#   inflating: /content/video_frames/crash_000042_frames.npz
#   inflating: /content/video_frames/crash_000266_frames.npz
#   inflating: /content/video_frames/normal_000206_frames.npz
#   inflating: /content/video_frames/normal_000463_frames.npz
#   inflating: /content/video_frames/normal_002530_frames.npz
#   inflating: /content/video_frames/crash_001473_frames.npz
#   inflating: /content/video_frames/normal_000482_frames.npz
#   inflating: /content/video_frames/crash_000529_frames.npz
#   inflating: /content/video_frames/normal_002030_frames.npz
#   inflating: /content/video_frames/normal_002960_frames.npz
#   inflating: /content/video_frames/normal_001490_frames.npz
#   inflating: /content/video_frames/crash_000917_frames.npz
#   inflating: /content/video_frames/crash_000142_frames.npz
#   inflating: /content/video_frames/normal_001247_frames.npz
#   inflating: /content/video_frames/crash_001177_frames.npz
#   inflating: /content/video_frames/normal_000866_frames.npz
#   inflating: /content/video_frames/normal_000634_frames.npz
#   inflating: /content/video_frames/normal_002160_frames.npz
#   inflating: /content/video_frames/normal_000527_frames.npz
#   inflating: /content/video_frames/normal_001496_frames.npz
#   inflating: /content/video_frames/normal_002429_frames.npz
#   inflating: /content/video_frames/normal_002533_frames.npz
#   inflating: /content/video_frames/normal_002561_frames.npz
#   inflating: /content/video_frames/normal_002021_frames.npz
#   inflating: /content/video_frames/normal_002394_frames.npz
#   inflating: /content/video_frames/normal_001557_frames.npz
#   inflating: /content/video_frames/normal_000483_frames.npz
#   inflating: /content/video_frames/normal_000218_frames.npz
#   inflating: /content/video_frames/crash_001062_frames.npz
#   inflating: /content/video_frames/normal_000516_frames.npz
#   inflating: /content/video_frames/normal_000118_frames.npz
#   inflating: /content/video_frames/normal_002733_frames.npz
#   inflating: /content/video_frames/normal_002307_frames.npz
#   inflating: /content/video_frames/crash_000931_frames.npz
#   inflating: /content/video_frames/normal_000768_frames.npz
#   inflating: /content/video_frames/normal_002500_frames.npz
#   inflating: /content/video_frames/crash_001368_frames.npz
#   inflating: /content/video_frames/crash_000083_frames.npz
#   inflating: /content/video_frames/normal_001728_frames.npz
#   inflating: /content/video_frames/crash_001140_frames.npz
#   inflating: /content/video_frames/normal_000613_frames.npz
#   inflating: /content/video_frames/normal_002137_frames.npz
#   inflating: /content/video_frames/normal_000733_frames.npz
#   inflating: /content/video_frames/normal_002484_frames.npz
#   inflating: /content/video_frames/normal_001509_frames.npz
#   inflating: /content/video_frames/normal_001093_frames.npz
#   inflating: /content/video_frames/normal_001708_frames.npz
#   inflating: /content/video_frames/crash_001051_frames.npz
#   inflating: /content/video_frames/normal_001672_frames.npz
#   inflating: /content/video_frames/normal_002679_frames.npz
#   inflating: /content/video_frames/normal_002373_frames.npz
#   inflating: /content/video_frames/normal_002680_frames.npz
#   inflating: /content/video_frames/crash_001383_frames.npz
#   inflating: /content/video_frames/normal_000149_frames.npz
#   inflating: /content/video_frames/normal_002188_frames.npz
#   inflating: /content/video_frames/normal_001565_frames.npz
#   inflating: /content/video_frames/crash_000565_frames.npz
#   inflating: /content/video_frames/normal_001769_frames.npz
#   inflating: /content/video_frames/normal_000105_frames.npz
#   inflating: /content/video_frames/normal_000404_frames.npz
#   inflating: /content/video_frames/normal_000533_frames.npz
#   inflating: /content/video_frames/normal_001083_frames.npz
#   inflating: /content/video_frames/normal_001011_frames.npz
#   inflating: /content/video_frames/normal_001292_frames.npz
#   inflating: /content/video_frames/crash_001077_frames.npz
#   inflating: /content/video_frames/crash_000628_frames.npz
#   inflating: /content/video_frames/crash_001411_frames.npz
#   inflating: /content/video_frames/normal_001908_frames.npz
#   inflating: /content/video_frames/normal_001074_frames.npz
#   inflating: /content/video_frames/normal_002770_frames.npz
#   inflating: /content/video_frames/normal_001916_frames.npz
#   inflating: /content/video_frames/crash_001020_frames.npz
#   inflating: /content/video_frames/normal_002265_frames.npz
#   inflating: /content/video_frames/normal_000251_frames.npz
#   inflating: /content/video_frames/normal_001168_frames.npz
#   inflating: /content/video_frames/normal_002855_frames.npz
#   inflating: /content/video_frames/normal_002809_frames.npz
#   inflating: /content/video_frames/normal_000070_frames.npz
#   inflating: /content/video_frames/normal_002962_frames.npz
#   inflating: /content/video_frames/normal_001730_frames.npz
#   inflating: /content/video_frames/normal_002571_frames.npz
#   inflating: /content/video_frames/crash_000554_frames.npz
#   inflating: /content/video_frames/normal_000379_frames.npz
#   inflating: /content/video_frames/normal_001087_frames.npz
#   inflating: /content/video_frames/normal_002305_frames.npz
#   inflating: /content/video_frames/normal_000235_frames.npz
#   inflating: /content/video_frames/normal_000423_frames.npz
#   inflating: /content/video_frames/normal_000728_frames.npz
#   inflating: /content/video_frames/normal_000843_frames.npz
#   inflating: /content/video_frames/normal_000819_frames.npz
#   inflating: /content/video_frames/normal_002054_frames.npz
#   inflating: /content/video_frames/normal_001464_frames.npz
#   inflating: /content/video_frames/normal_002572_frames.npz
# ...
#   inflating: /content/video_frames/crash_000104_frames.npz
#   inflating: /content/video_frames/crash_000778_frames.npz
#   inflating: /content/video_frames/normal_000900_frames.npz
#   inflating: /content/video_frames/normal_000520_frames.npz
#   inflating: /content/video_frames/normal_002517_frames.npz
#   inflating: /content/video_frames/normal_002235_frames.npz
#   inflating: /content/video_frames/crash_000434_frames.npz
#   inflating: /content/video_frames/normal_002555_frames.npz
#   inflating: /content/video_frames/crash_000997_frames.npz
#   inflating: /content/video_frames/crash_000490_frames.npz
#   inflating: /content/video_frames/normal_002096_frames.npz
#   inflating: /content/video_frames/normal_000308_frames.npz
#   inflating: /content/video_frames/normal_002795_frames.npz
#   inflating: /content/video_frames/crash_001269_frames.npz
#   inflating: /content/video_frames/crash_000356_frames.npz
#   inflating: /content/video_frames/normal_001995_frames.npz
#   inflating: /content/video_frames/crash_001323_frames.npz
#   inflating: /content/video_frames/normal_000837_frames.npz
#   inflating: /content/video_frames/normal_002111_frames.npz
#   inflating: /content/video_frames/normal_001584_frames.npz
#   inflating: /content/video_frames/normal_001580_frames.npz
#   inflating: /content/video_frames/normal_001568_frames.npz
#   inflating: /content/video_frames/normal_001642_frames.npz
#   inflating: /content/video_frames/normal_002790_frames.npz
#   inflating: /content/video_frames/normal_000271_frames.npz
#   inflating: /content/video_frames/normal_001555_frames.npz
#   inflating: /content/video_frames/normal_001279_frames.npz
#   inflating: /content/video_frames/normal_000618_frames.npz
#   inflating: /content/video_frames/normal_000745_frames.npz
#   inflating: /content/video_frames/normal_002024_frames.npz
#   inflating: /content/video_frames/crash_000862_frames.npz
#   inflating: /content/video_frames/crash_001279_frames.npz
#   inflating: /content/video_frames/normal_000508_frames.npz
#   inflating: /content/video_frames/normal_001645_frames.npz
#   inflating: /content/video_frames/crash_000746_frames.npz
#   inflating: /content/video_frames/normal_002670_frames.npz
#   inflating: /content/video_frames/normal_002853_frames.npz
#   inflating: /content/video_frames/normal_002301_frames.npz
#   inflating: /content/video_frames/normal_002358_frames.npz
#   inflating: /content/video_frames/crash_000173_frames.npz
#   inflating: /content/video_frames/normal_000274_frames.npz
#   inflating: /content/video_frames/normal_000792_frames.npz
#   inflating: /content/video_frames/normal_000449_frames.npz
#   inflating: /content/video_frames/normal_001344_frames.npz
#   inflating: /content/video_frames/normal_000824_frames.npz
#   inflating: /content/video_frames/normal_001702_frames.npz
#   inflating: /content/video_frames/normal_001448_frames.npz
#   inflating: /content/video_frames/normal_001454_frames.npz
#   inflating: /content/video_frames/normal_001540_frames.npz
#   inflating: /content/video_frames/normal_000902_frames.npz
#   inflating: /content/video_frames/normal_002165_frames.npz
#   inflating: /content/video_frames/normal_001078_frames.npz
#   inflating: /content/video_frames/crash_000891_frames.npz
#   inflating: /content/video_frames/normal_001841_frames.npz
#   inflating: /content/video_frames/normal_000305_frames.npz
#   inflating: /content/video_frames/normal_002016_frames.npz
#   inflating: /content/video_frames/normal_000767_frames.npz
#   inflating: /content/video_frames/normal_001524_frames.npz
#   inflating: /content/video_frames/normal_001072_frames.npz
#   inflating: /content/video_frames/normal_002257_frames.npz
#   inflating: /content/video_frames/normal_000010_frames.npz
#   inflating: /content/video_frames/normal_001613_frames.npz
#   inflating: /content/video_frames/crash_000511_frames.npz
#   inflating: /content/video_frames/normal_000565_frames.npz
#   inflating: /content/video_frames/normal_002460_frames.npz
#   inflating: /content/video_frames/normal_000111_frames.npz
#   inflating: /content/video_frames/crash_001500_frames.npz
#   inflating: /content/video_frames/normal_002864_frames.npz
#   inflating: /content/video_frames/normal_002660_frames.npz
#   inflating: /content/video_frames/crash_000574_frames.npz
#   inflating: /content/video_frames/normal_000885_frames.npz
#   inflating: /content/video_frames/normal_000192_frames.npz
#   inflating: /content/video_frames/normal_000647_frames.npz
#   inflating: /content/video_frames/normal_000953_frames.npz
#   inflating: /content/video_frames/normal_000008_frames.npz
#   inflating: /content/video_frames/normal_001034_frames.npz
#   inflating: /content/video_frames/normal_002808_frames.npz
#   inflating: /content/video_frames/normal_002183_frames.npz
#   inflating: /content/video_frames/normal_000989_frames.npz
#   inflating: /content/video_frames/normal_001183_frames.npz
#   inflating: /content/video_frames/normal_002874_frames.npz
#   inflating: /content/video_frames/normal_002759_frames.npz
#   inflating: /content/video_frames/normal_002189_frames.npz
#   inflating: /content/video_frames/normal_002333_frames.npz
#   inflating: /content/video_frames/normal_001437_frames.npz
#   inflating: /content/video_frames/normal_002220_frames.npz
#   inflating: /content/video_frames/normal_001369_frames.npz
#   inflating: /content/video_frames/normal_000838_frames.npz
#   inflating: /content/video_frames/normal_002071_frames.npz
#   inflating: /content/video_frames/normal_002552_frames.npz
#   inflating: /content/video_frames/normal_000919_frames.npz
#   inflating: /content/video_frames/normal_001575_frames.npz
#   inflating: /content/video_frames/crash_000586_frames.npz
#   inflating: /content/video_frames/crash_001142_frames.npz
#   inflating: /content/video_frames/normal_002444_frames.npz
#   inflating: /content/video_frames/normal_002422_frames.npz
#   inflating: /content/video_frames/normal_002727_frames.npz
#   inflating: /content/video_frames/normal_001474_frames.npz
#   inflating: /content/video_frames/normal_001204_frames.npz
#   inflating: /content/video_frames/normal_002972_frames.npz
#   inflating: /content/video_frames/normal_000017_frames.npz
#   inflating: /content/video_frames/crash_001154_frames.npz
#   inflating: /content/video_frames/normal_001880_frames.npz
#   inflating: /content/video_frames/normal_001422_frames.npz
#   inflating: /content/video_frames/normal_002583_frames.npz
#   inflating: /content/video_frames/crash_000031_frames.npz
#   inflating: /content/video_frames/normal_000252_frames.npz
#   inflating: /content/video_frames/normal_001445_frames.npz
#   inflating: /content/video_frames/normal_002261_frames.npz
#   inflating: /content/video_frames/normal_001618_frames.npz
#   inflating: /content/video_frames/normal_002980_frames.npz
#   inflating: /content/video_frames/normal_001009_frames.npz
#   inflating: /content/video_frames/normal_002706_frames.npz
#   inflating: /content/video_frames/normal_000675_frames.npz
#   inflating: /content/video_frames/normal_002486_frames.npz
#   inflating: /content/video_frames/normal_001538_frames.npz
#   inflating: /content/video_frames/crash_001312_frames.npz
#   inflating: /content/video_frames/normal_002549_frames.npz
#   inflating: /content/video_frames/normal_000398_frames.npz
#   inflating: /content/video_frames/crash_000502_frames.npz
#   inflating: /content/video_frames/normal_002171_frames.npz
#   inflating: /content/video_frames/crash_000811_frames.npz
#   inflating: /content/video_frames/crash_000271_frames.npz
#   inflating: /content/video_frames/normal_002503_frames.npz
#   inflating: /content/video_frames/normal_001525_frames.npz
#   inflating: /content/video_frames/normal_000048_frames.npz
#   inflating: /content/video_frames/normal_002984_frames.npz
#   inflating: /content/video_frames/normal_001489_frames.npz
#   inflating: /content/video_frames/normal_000868_frames.npz
#   inflating: /content/video_frames/normal_000896_frames.npz
#   inflating: /content/video_frames/normal_001466_frames.npz
#   inflating: /content/video_frames/crash_001486_frames.npz
#   inflating: /content/video_frames/normal_001735_frames.npz
#   inflating: /content/video_frames/normal_002217_frames.npz
#   inflating: /content/video_frames/normal_001157_frames.npz
#   inflating: /content/video_frames/normal_002463_frames.npz
#   inflating: /content/video_frames/normal_000411_frames.npz
#   inflating: /content/video_frames/normal_001508_frames.npz
#   inflating: /content/video_frames/normal_000769_frames.npz
#   inflating: /content/video_frames/normal_001814_frames.npz
#   inflating: /content/video_frames/normal_001686_frames.npz
#   inflating: /content/video_frames/normal_000827_frames.npz
#   inflating: /content/video_frames/normal_002607_frames.npz
#   inflating: /content/video_frames/normal_002536_frames.npz
#   inflating: /content/video_frames/normal_000475_frames.npz
#   inflating: /content/video_frames/normal_000131_frames.npz
#   inflating: /content/video_frames/normal_000068_frames.npz
#   inflating: /content/video_frames/normal_000030_frames.npz
#   inflating: /content/video_frames/normal_001479_frames.npz
#   inflating: /content/video_frames/normal_000073_frames.npz
#   inflating: /content/video_frames/normal_000166_frames.npz
#   inflating: /content/video_frames/normal_001909_frames.npz
#   inflating: /content/video_frames/crash_000509_frames.npz
#   inflating: /content/video_frames/normal_000375_frames.npz
#   inflating: /content/video_frames/normal_002754_frames.npz
#   inflating: /content/video_frames/crash_000503_frames.npz
#   inflating: /content/video_frames/normal_000593_frames.npz
#   inflating: /content/video_frames/normal_002973_frames.npz
#   inflating: /content/video_frames/crash_000710_frames.npz
#   inflating: /content/video_frames/normal_001315_frames.npz
#   inflating: /content/video_frames/normal_001844_frames.npz
#   inflating: /content/video_frames/normal_000063_frames.npz
#   inflating: /content/video_frames/normal_000156_frames.npz
#   inflating: /content/video_frames/normal_001784_frames.npz
#   inflating: /content/video_frames/normal_002735_frames.npz
#   inflating: /content/video_frames/normal_001029_frames.npz
#   inflating: /content/video_frames/crash_001288_frames.npz
#   inflating: /content/video_frames/normal_000992_frames.npz
#   inflating: /content/video_frames/normal_001460_frames.npz
#   inflating: /content/video_frames/normal_002557_frames.npz
#   inflating: /content/video_frames/normal_002879_frames.npz
#   inflating: /content/video_frames/crash_000377_frames.npz
#   inflating: /content/video_frames/normal_001657_frames.npz
#   inflating: /content/video_frames/normal_001298_frames.npz
#   inflating: /content/video_frames/normal_002799_frames.npz
#   inflating: /content/video_frames/normal_001222_frames.npz
#   inflating: /content/video_frames/normal_001382_frames.npz
#   inflating: /content/video_frames/normal_002085_frames.npz
#   inflating: /content/video_frames/normal_002002_frames.npz
#   inflating: /content/video_frames/normal_002064_frames.npz
#   inflating: /content/video_frames/normal_000978_frames.npz
#   inflating: /content/video_frames/normal_000602_frames.npz
#   inflating: /content/video_frames/crash_001135_frames.npz
#   inflating: /content/video_frames/normal_000465_frames.npz
#   inflating: /content/video_frames/normal_002393_frames.npz
#   inflating: /content/video_frames/normal_002927_frames.npz
#   inflating: /content/video_frames/normal_002563_frames.npz
#   inflating: /content/video_frames/crash_001325_frames.npz
#   inflating: /content/video_frames/normal_001522_frames.npz
#   inflating: /content/video_frames/normal_002537_frames.npz
#   inflating: /content/video_frames/normal_001092_frames.npz
#   inflating: /content/video_frames/normal_001535_frames.npz
#   inflating: /content/video_frames/normal_000686_frames.npz
#   inflating: /content/video_frames/crash_000363_frames.npz
#   inflating: /content/video_frames/normal_002664_frames.npz
#   inflating: /content/video_frames/normal_000046_frames.npz
#   inflating: /content/video_frames/normal_002569_frames.npz
#   inflating: /content/video_frames/normal_001407_frames.npz
#   inflating: /content/video_frames/normal_000151_frames.npz
#   inflating: /content/video_frames/normal_000229_frames.npz
#   inflating: /content/video_frames/crash_000020_frames.npz
#   inflating: /content/video_frames/normal_001550_frames.npz
#   inflating: /content/video_frames/normal_000140_frames.npz
#   inflating: /content/video_frames/normal_002714_frames.npz
#   inflating: /content/video_frames/normal_000668_frames.npz
#   inflating: /content/video_frames/normal_001381_frames.npz
#   inflating: /content/video_frames/crash_000413_frames.npz
#   inflating: /content/video_frames/normal_001724_frames.npz
#   inflating: /content/video_frames/crash_000932_frames.npz
#   inflating: /content/video_frames/normal_001431_frames.npz
#   inflating: /content/video_frames/normal_001585_frames.npz
#   inflating: /content/video_frames/normal_002748_frames.npz
#   inflating: /content/video_frames/crash_000496_frames.npz
#   inflating: /content/video_frames/crash_000464_frames.npz
#   inflating: /content/video_frames/crash_000614_frames.npz
#   inflating: /content/video_frames/normal_001670_frames.npz
#   inflating: /content/video_frames/normal_000447_frames.npz
#   inflating: /content/video_frames/crash_001189_frames.npz
#   inflating: /content/video_frames/crash_000649_frames.npz
#   inflating: /content/video_frames/normal_001405_frames.npz
#   inflating: /content/video_frames/normal_001830_frames.npz
#   inflating: /content/video_frames/normal_000969_frames.npz
#   inflating: /content/video_frames/normal_002685_frames.npz
#   inflating: /content/video_frames/normal_002465_frames.npz
#   inflating: /content/video_frames/normal_002525_frames.npz
#   inflating: /content/video_frames/crash_001388_frames.npz
#   inflating: /content/video_frames/normal_000421_frames.npz
#   inflating: /content/video_frames/crash_001175_frames.npz
#   inflating: /content/video_frames/normal_001086_frames.npz
#   inflating: /content/video_frames/crash_000818_frames.npz
#   inflating: /content/video_frames/normal_001611_frames.npz
#   inflating: /content/video_frames/normal_001397_frames.npz
#   inflating: /content/video_frames/crash_000359_frames.npz
#   inflating: /content/video_frames/normal_001678_frames.npz
#   inflating: /content/video_frames/normal_002629_frames.npz
#   inflating: /content/video_frames/normal_000170_frames.npz
#   inflating: /content/video_frames/normal_001109_frames.npz
#   inflating: /content/video_frames/normal_000495_frames.npz
#   inflating: /content/video_frames/normal_001639_frames.npz
#   inflating: /content/video_frames/normal_002428_frames.npz
#   inflating: /content/video_frames/normal_002141_frames.npz
#   inflating: /content/video_frames/crash_001170_frames.npz
#   inflating: /content/video_frames/crash_001494_frames.npz
#   inflating: /content/video_frames/normal_000643_frames.npz
#   inflating: /content/video_frames/normal_002997_frames.npz
#   inflating: /content/video_frames/normal_000253_frames.npz
#   inflating: /content/video_frames/crash_001427_frames.npz
#   inflating: /content/video_frames/normal_000645_frames.npz
#   inflating: /content/video_frames/normal_002464_frames.npz
#   inflating: /content/video_frames/normal_002379_frames.npz
#   inflating: /content/video_frames/normal_002965_frames.npz
#   inflating: /content/video_frames/normal_002694_frames.npz
#   inflating: /content/video_frames/normal_001499_frames.npz
#   inflating: /content/video_frames/normal_000233_frames.npz
#   inflating: /content/video_frames/normal_002848_frames.npz
#   inflating: /content/video_frames/normal_001649_frames.npz
#   inflating: /content/video_frames/normal_000090_frames.npz
#   inflating: /content/video_frames/normal_002656_frames.npz

# %% [markdown]
# ## Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# !pip install mlflow
import mlflow
from mlflow.models import infer_signature
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

# %%
# export MLFLOW_TRACKING_URI=http://localhost:5000
mlflow.login()
mlflow.set_tracking_uri("databricks")
mlflow.set_experiment("/ESP3201_car_crash_prediction")
# https://community.cloud.databricks.com
# ziyi_ng@u.nus.edu
# ESP3201project@

# %% [markdown]
# ## Functions

# %%
normal_video_path = "/content/videos/normal"

def extract_frames(video_path, first_frame=None, last_frame=None, output_size=(128, 128)):
  cap = cv2.VideoCapture(video_path)
  frames = []
  frame_count = 0

  # Detect border based on first frame so that border width is not recalculated for every frame
  # for some reason, if recalculated, the border width may change to 0 midway through the video
  ret, sample_frame = cap.read()
  height, width, _ = sample_frame.shape
  border_width = np.argmax(np.mean(sample_frame, axis=0) > 0)
  if border_width * 2 >= width:
      border_width = 0

  if not cap.isOpened():
      print(f"Error: Unable to open video file {video_path}")

  if first_frame is not None:
    cap.set(cv2.CAP_PROP_POS_FRAMES, first_frame)

  while cap.isOpened() and frame_count < 30:
      ret, frame = cap.read()
      if not ret:
          break

      frame = frame[:, border_width: int(width - border_width)]

      rgb_frame = frame[..., ::-1]

      resized_frame = cv2.resize(rgb_frame, output_size)
      normalized_frame = resized_frame / 255.0

      frames.append(normalized_frame)
      frame_count += 1
  cap.release()
  if frame_count == 30:
    frames = np.array(frames)
    return frames

  else:
    print(f"Warning: Only {len(frames)} frames were captured.")
    return None

def get_frames_before_accident(video_path, binlabels, frame_count=30):
    """
    Retrieve 30 frames before the first accident frame (where binlabels[i] == 1).
    """
    first_accident_frame = next((i for i, label in enumerate(binlabels) if label == 1), None)

    if first_accident_frame is None or first_accident_frame < frame_count:
        return None  # Not enough frames before accident or no accident frame

    first_frame = first_accident_frame - frame_count
    return first_frame, first_accident_frame

# Filter for egocentric videos according to text file data
def filter_egocentric_videos(txt_file):
  egocentric_txt = '/content/egocentric_videos.txt'
  egoinvolve_count = 0
  egocentric_videos = []
  with open(txt_file, 'r') as txt_file, open(egocentric_txt, 'w') as egocentric_txt:
      for line in txt_file:
          data = line.strip().split(',', 1)

          vidname = data[0].strip()

          temp = data[1].strip().split('[,', 1)
          data = temp[0].strip().split(']', 1)
          binlabels_str = data[0].replace('[','').replace(']','')
          data = data[1].replace(',', '', 1).split(',', 4)

          binlabels = list(map(int, binlabels_str.split(',')))

          startframe = data[0]
          youtubeID = data[1].strip()
          timing = data[2].strip()
          weather = data[3].strip()
          egoinvolve = data[4].strip()

          if egoinvolve == 'Yes':
              egoinvolve_count += 1
              egocentric_txt.write(line)
              egocentric_videos.append({
                  "vidname": vidname,
                  "binlabels": binlabels,
                  "startframe": startframe,
                  "youtubeID": youtubeID,
                  "timing": timing,
                  "weather": weather
              })

  return egocentric_videos

# %%
# @title data quality check

import os
import pandas as pd

normal_video_dir = '/content/videos/normal'
crash_video_dir = '/content/videos/car_crash'

def calculate_sharpness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    laplacian_var = cv2.Laplacian(gray, cv2.CV_64F).var()
    return laplacian_var

def remove_black_borders(frame):
    height, width, _ = frame.shape

    border_width = np.argmax(np.mean(frame, axis=0) > 0)

    if border_width * 2 >= width:
        border_width = 0  # Reset if the border width is too large

    frame = frame[:, border_width:int(width - border_width)]
    return frame

def check_video_quality(video_path):
    results = {}
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Error opening video file: {video_path}")
        results['video_name'] = os.path.basename(video_path)
        results['error'] = f"Error opening video file: {video_path}"
        return results  # Return error in results

    original_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    original_aspect_ratio = original_width / original_height
    print(f"Original dimensions: {original_width}x{original_height}")

    cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
    ret, frame = cap.read()

    if ret:
        frame = remove_black_borders(frame)

        plt.figure(figsize=(6, 6))
        plt.title(f"Processed Frame from {os.path.basename(video_path)}")
        plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

        resized_frame = cv2.resize(frame, (128, 128))
        resized_aspect_ratio = 128 / 128

        print(f"Original aspect ratio: {original_aspect_ratio:.2f}, Resized aspect ratio: {resized_aspect_ratio:.2f}")

        plt.figure(figsize=(6, 6))
        plt.title(f"Resized Frame (128x128) from {os.path.basename(video_path)}")
        plt.imshow(cv2.cvtColor(resized_frame, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

        original_sharpness = calculate_sharpness(frame)
        resized_sharpness = calculate_sharpness(resized_frame)
        print(f"Original Sharpness (Laplacian variance): {original_sharpness:.2f}")
        print(f"Resized Sharpness (Laplacian variance): {resized_sharpness:.2f}")

        results['video_name'] = os.path.basename(video_path)
        results['original_sharpness'] = original_sharpness
        results['resized_sharpness'] = resized_sharpness
        results['error'] = None
    else:
        results['video_name'] = os.path.basename(video_path)
        results['error'] = f"Error reading frame from {video_path}"

    cap.release()
    return results

egocentric_videos = filter_egocentric_videos("/content/Crash-1500.txt")
pos_sample = [34, 984, 200, 495, 881, 440, 516, 688, 1151, 1422]
neg_sample = [314, 2158, 1281, 1638, 147, 2123, 1773, 492, 1254, 1879]

results_summary = []

for i in neg_sample:
    video_name = f"{i:06d}.mp4"
    video_path = os.path.join(normal_video_dir, video_name)
    print(f"\nChecking video: {video_name}")
    result = check_video_quality(video_path)
    results_summary.append(result)

for i in pos_sample:
    video_name = f"{i:06d}.mp4"
    video_path = os.path.join(crash_video_dir, video_name)
    print(f"\nChecking random egocentric video: {video_name}")
    result = check_video_quality(video_path)
    results_summary.append(result)

results_df = pd.DataFrame(results_summary)

print("\nSummary of Video Quality Checks:")
print(results_df)

# %% [markdown]
# ## **Processing**

# %%
import random
import numpy as np

total_videos = 3000
selected_videos = random.sample(range(total_videos), 250)
count = 0
for i in range(1, total_videos+1):
  video_id = f"{i:06d}"
  video_path = f"/content/videos/normal/{video_id}.mp4"
  print(video_path)
  frames_file_path = f"/content/video_frames/normal_{video_id}_frames.npz"
  np.savez_compressed(frames_file_path,
                      frames=extract_frames(video_path=video_path),
                      label = 0)
  count += 1
  if count % 10 == 0 and count > 0:
    print(f"Processed {count} normal videos.")
# Out:
# /content/videos/normal/000001.mp4
# /content/videos/normal/000002.mp4
# /content/videos/normal/000003.mp4
# /content/videos/normal/000004.mp4
# /content/videos/normal/000005.mp4
# /content/videos/normal/000006.mp4
# /content/videos/normal/000007.mp4
# /content/videos/normal/000008.mp4
# /content/videos/normal/000009.mp4
# /content/videos/normal/000010.mp4
# Processed 10 normal videos.
# /content/videos/normal/000011.mp4
# /content/videos/normal/000012.mp4
# /content/videos/normal/000013.mp4
# /content/videos/normal/000014.mp4
# /content/videos/normal/000015.mp4
# /content/videos/normal/000016.mp4
# /content/videos/normal/000017.mp4
# /content/videos/normal/000018.mp4
# /content/videos/normal/000019.mp4
# /content/videos/normal/000020.mp4
# Processed 20 normal videos.
# /content/videos/normal/000021.mp4
# /content/videos/normal/000022.mp4
# /content/videos/normal/000023.mp4
# /content/videos/normal/000024.mp4
# /content/videos/normal/000025.mp4
# /content/videos/normal/000026.mp4
# /content/videos/normal/000027.mp4
# /content/videos/normal/000028.mp4
# /content/videos/normal/000029.mp4
# /content/videos/normal/000030.mp4
# Processed 30 normal videos.
# /content/videos/normal/000031.mp4
# /content/videos/normal/000032.mp4
# /content/videos/normal/000033.mp4
# /content/videos/normal/000034.mp4
# /content/videos/normal/000035.mp4
# /content/videos/normal/000036.mp4
# /content/videos/normal/000037.mp4
# /content/videos/normal/000038.mp4
# /content/videos/normal/000039.mp4
# /content/videos/normal/000040.mp4
# Processed 40 normal videos.
# /content/videos/normal/000041.mp4
# /content/videos/normal/000042.mp4
# /content/videos/normal/000043.mp4
# /content/videos/normal/000044.mp4
# /content/videos/normal/000045.mp4
# /content/videos/normal/000046.mp4
# /content/videos/normal/000047.mp4
# /content/videos/normal/000048.mp4
# /content/videos/normal/000049.mp4
# /content/videos/normal/000050.mp4
# Processed 50 normal videos.
# /content/videos/normal/000051.mp4
# /content/videos/normal/000052.mp4
# /content/videos/normal/000053.mp4
# /content/videos/normal/000054.mp4
# /content/videos/normal/000055.mp4
# /content/videos/normal/000056.mp4
# /content/videos/normal/000057.mp4
# /content/videos/normal/000058.mp4
# /content/videos/normal/000059.mp4
# /content/videos/normal/000060.mp4
# Processed 60 normal videos.
# /content/videos/normal/000061.mp4
# /content/videos/normal/000062.mp4
# /content/videos/normal/000063.mp4
# /content/videos/normal/000064.mp4
# /content/videos/normal/000065.mp4
# /content/videos/normal/000066.mp4
# /content/videos/normal/000067.mp4
# /content/videos/normal/000068.mp4
# /content/videos/normal/000069.mp4
# /content/videos/normal/000070.mp4
# Processed 70 normal videos.
# /content/videos/normal/000071.mp4
# /content/videos/normal/000072.mp4
# /content/videos/normal/000073.mp4
# /content/videos/normal/000074.mp4
# /content/videos/normal/000075.mp4
# /content/videos/normal/000076.mp4
# /content/videos/normal/000077.mp4
# /content/videos/normal/000078.mp4
# /content/videos/normal/000079.mp4
# /content/videos/normal/000080.mp4
# Processed 80 normal videos.
# /content/videos/normal/000081.mp4
# /content/videos/normal/000082.mp4
# /content/videos/normal/000083.mp4
# /content/videos/normal/000084.mp4
# /content/videos/normal/000085.mp4
# /content/videos/normal/000086.mp4
# /content/videos/normal/000087.mp4
# /content/videos/normal/000088.mp4
# /content/videos/normal/000089.mp4
# /content/videos/normal/000090.mp4
# Processed 90 normal videos.
# /content/videos/normal/000091.mp4
# /content/videos/normal/000092.mp4
# /content/videos/normal/000093.mp4
# /content/videos/normal/000094.mp4
# /content/videos/normal/000095.mp4
# /content/videos/normal/000096.mp4
# /content/videos/normal/000097.mp4
# /content/videos/normal/000098.mp4
# /content/videos/normal/000099.mp4
# /content/videos/normal/000100.mp4
# Processed 100 normal videos.
# /content/videos/normal/000101.mp4
# /content/videos/normal/000102.mp4
# /content/videos/normal/000103.mp4
# /content/videos/normal/000104.mp4
# /content/videos/normal/000105.mp4
# /content/videos/normal/000106.mp4
# /content/videos/normal/000107.mp4
# /content/videos/normal/000108.mp4
# /content/videos/normal/000109.mp4
# /content/videos/normal/000110.mp4
# Processed 110 normal videos.
# /content/videos/normal/000111.mp4
# /content/videos/normal/000112.mp4
# /content/videos/normal/000113.mp4
# /content/videos/normal/000114.mp4
# /content/videos/normal/000115.mp4
# /content/videos/normal/000116.mp4
# /content/videos/normal/000117.mp4
# /content/videos/normal/000118.mp4
# /content/videos/normal/000119.mp4
# /content/videos/normal/000120.mp4
# Processed 120 normal videos.
# /content/videos/normal/000121.mp4
# /content/videos/normal/000122.mp4
# /content/videos/normal/000123.mp4
# /content/videos/normal/000124.mp4
# /content/videos/normal/000125.mp4
# /content/videos/normal/000126.mp4
# /content/videos/normal/000127.mp4
# /content/videos/normal/000128.mp4
# /content/videos/normal/000129.mp4
# /content/videos/normal/000130.mp4
# Processed 130 normal videos.
# /content/videos/normal/000131.mp4
# /content/videos/normal/000132.mp4
# /content/videos/normal/000133.mp4
# /content/videos/normal/000134.mp4
# /content/videos/normal/000135.mp4
# /content/videos/normal/000136.mp4
# /content/videos/normal/000137.mp4
# /content/videos/normal/000138.mp4
# /content/videos/normal/000139.mp4
# /content/videos/normal/000140.mp4
# Processed 140 normal videos.
# /content/videos/normal/000141.mp4
# /content/videos/normal/000142.mp4
# /content/videos/normal/000143.mp4
# /content/videos/normal/000144.mp4
# /content/videos/normal/000145.mp4
# /content/videos/normal/000146.mp4
# /content/videos/normal/000147.mp4
# /content/videos/normal/000148.mp4
# /content/videos/normal/000149.mp4
# /content/videos/normal/000150.mp4
# Processed 150 normal videos.
# /content/videos/normal/000151.mp4
# /content/videos/normal/000152.mp4
# /content/videos/normal/000153.mp4
# /content/videos/normal/000154.mp4
# /content/videos/normal/000155.mp4
# /content/videos/normal/000156.mp4
# /content/videos/normal/000157.mp4
# /content/videos/normal/000158.mp4
# /content/videos/normal/000159.mp4
# /content/videos/normal/000160.mp4
# Processed 160 normal videos.
# /content/videos/normal/000161.mp4
# /content/videos/normal/000162.mp4
# /content/videos/normal/000163.mp4
# /content/videos/normal/000164.mp4
# /content/videos/normal/000165.mp4
# /content/videos/normal/000166.mp4
# /content/videos/normal/000167.mp4
# /content/videos/normal/000168.mp4
# /content/videos/normal/000169.mp4
# /content/videos/normal/000170.mp4
# Processed 170 normal videos.
# /content/videos/normal/000171.mp4
# /content/videos/normal/000172.mp4
# /content/videos/normal/000173.mp4
# /content/videos/normal/000174.mp4
# /content/videos/normal/000175.mp4
# /content/videos/normal/000176.mp4
# /content/videos/normal/000177.mp4
# /content/videos/normal/000178.mp4
# /content/videos/normal/000179.mp4
# /content/videos/normal/000180.mp4
# Processed 180 normal videos.
# /content/videos/normal/000181.mp4
# /content/videos/normal/000182.mp4
# /content/videos/normal/000183.mp4
# /content/videos/normal/000184.mp4
# /content/videos/normal/000185.mp4
# /content/videos/normal/000186.mp4
# /content/videos/normal/000187.mp4
# /content/videos/normal/000188.mp4
# /content/videos/normal/000189.mp4
# /content/videos/normal/000190.mp4
# Processed 190 normal videos.
# /content/videos/normal/000191.mp4
# /content/videos/normal/000192.mp4
# /content/videos/normal/000193.mp4
# /content/videos/normal/000194.mp4
# /content/videos/normal/000195.mp4
# /content/videos/normal/000196.mp4
# /content/videos/normal/000197.mp4
# /content/videos/normal/000198.mp4
# /content/videos/normal/000199.mp4
# /content/videos/normal/000200.mp4
# Processed 200 normal videos.
# /content/videos/normal/000201.mp4
# /content/videos/normal/000202.mp4
# /content/videos/normal/000203.mp4
# /content/videos/normal/000204.mp4
# /content/videos/normal/000205.mp4
# /content/videos/normal/000206.mp4
# /content/videos/normal/000207.mp4
# /content/videos/normal/000208.mp4
# /content/videos/normal/000209.mp4
# /content/videos/normal/000210.mp4
# Processed 210 normal videos.
# /content/videos/normal/000211.mp4
# /content/videos/normal/000212.mp4
# /content/videos/normal/000213.mp4
# /content/videos/normal/000214.mp4
# /content/videos/normal/000215.mp4
# /content/videos/normal/000216.mp4
# /content/videos/normal/000217.mp4
# /content/videos/normal/000218.mp4
# /content/videos/normal/000219.mp4
# /content/videos/normal/000220.mp4
# Processed 220 normal videos.
# /content/videos/normal/000221.mp4
# /content/videos/normal/000222.mp4
# /content/videos/normal/000223.mp4
# /content/videos/normal/000224.mp4
# /content/videos/normal/000225.mp4
# /content/videos/normal/000226.mp4
# /content/videos/normal/000227.mp4
# /content/videos/normal/000228.mp4
# /content/videos/normal/000229.mp4
# /content/videos/normal/000230.mp4
# Processed 230 normal videos.
# /content/videos/normal/000231.mp4
# /content/videos/normal/000232.mp4
# /content/videos/normal/000233.mp4
# /content/videos/normal/000234.mp4
# /content/videos/normal/000235.mp4
# /content/videos/normal/000236.mp4
# /content/videos/normal/000237.mp4
# /content/videos/normal/000238.mp4
# /content/videos/normal/000239.mp4
# /content/videos/normal/000240.mp4
# Processed 240 normal videos.
# /content/videos/normal/000241.mp4
# /content/videos/normal/000242.mp4
# /content/videos/normal/000243.mp4
# /content/videos/normal/000244.mp4
# /content/videos/normal/000245.mp4
# /content/videos/normal/000246.mp4
# /content/videos/normal/000247.mp4
# /content/videos/normal/000248.mp4
# /content/videos/normal/000249.mp4
# /content/videos/normal/000250.mp4
# Processed 250 normal videos.
# /content/videos/normal/000251.mp4
# /content/videos/normal/000252.mp4
# /content/videos/normal/000253.mp4
# /content/videos/normal/000254.mp4
# /content/videos/normal/000255.mp4
# /content/videos/normal/000256.mp4
# /content/videos/normal/000257.mp4
# /content/videos/normal/000258.mp4
# /content/videos/normal/000259.mp4
# /content/videos/normal/000260.mp4
# Processed 260 normal videos.
# /content/videos/normal/000261.mp4
# /content/videos/normal/000262.mp4
# /content/videos/normal/000263.mp4
# /content/videos/normal/000264.mp4
# /content/videos/normal/000265.mp4
# /content/videos/normal/000266.mp4
# /content/videos/normal/000267.mp4
# /content/videos/normal/000268.mp4
# /content/videos/normal/000269.mp4
# /content/videos/normal/000270.mp4
# Processed 270 normal videos.
# /content/videos/normal/000271.mp4
# /content/videos/normal/000272.mp4
# /content/videos/normal/000273.mp4
# /content/videos/normal/000274.mp4
# /content/videos/normal/000275.mp4
# /content/videos/normal/000276.mp4
# /content/videos/normal/000277.mp4
# /content/videos/normal/000278.mp4
# /content/videos/normal/000279.mp4
# /content/videos/normal/000280.mp4
# Processed 280 normal videos.
# /content/videos/normal/000281.mp4
# /content/videos/normal/000282.mp4
# /content/videos/normal/000283.mp4
# /content/videos/normal/000284.mp4
# /content/videos/normal/000285.mp4
# /content/videos/normal/000286.mp4
# /content/videos/normal/000287.mp4
# /content/videos/normal/000288.mp4
# /content/videos/normal/000289.mp4
# /content/videos/normal/000290.mp4
# Processed 290 normal videos.
# /content/videos/normal/000291.mp4
# /content/videos/normal/000292.mp4
# /content/videos/normal/000293.mp4
# /content/videos/normal/000294.mp4
# /content/videos/normal/000295.mp4
# /content/videos/normal/000296.mp4
# /content/videos/normal/000297.mp4
# /content/videos/normal/000298.mp4
# /content/videos/normal/000299.mp4
# /content/videos/normal/000300.mp4
# Processed 300 normal videos.
# /content/videos/normal/000301.mp4
# /content/videos/normal/000302.mp4
# /content/videos/normal/000303.mp4
# /content/videos/normal/000304.mp4
# /content/videos/normal/000305.mp4
# /content/videos/normal/000306.mp4
# /content/videos/normal/000307.mp4
# /content/videos/normal/000308.mp4
# /content/videos/normal/000309.mp4
# /content/videos/normal/000310.mp4
# Processed 310 normal videos.
# /content/videos/normal/000311.mp4
# /content/videos/normal/000312.mp4
# /content/videos/normal/000313.mp4
# /content/videos/normal/000314.mp4
# /content/videos/normal/000315.mp4
# /content/videos/normal/000316.mp4
# /content/videos/normal/000317.mp4
# /content/videos/normal/000318.mp4
# /content/videos/normal/000319.mp4
# /content/videos/normal/000320.mp4
# Processed 320 normal videos.
# /content/videos/normal/000321.mp4
# /content/videos/normal/000322.mp4
# /content/videos/normal/000323.mp4
# /content/videos/normal/000324.mp4
# /content/videos/normal/000325.mp4
# /content/videos/normal/000326.mp4
# /content/videos/normal/000327.mp4
# /content/videos/normal/000328.mp4
# /content/videos/normal/000329.mp4
# /content/videos/normal/000330.mp4
# Processed 330 normal videos.
# /content/videos/normal/000331.mp4
# /content/videos/normal/000332.mp4
# /content/videos/normal/000333.mp4
# /content/videos/normal/000334.mp4
# /content/videos/normal/000335.mp4
# /content/videos/normal/000336.mp4
# /content/videos/normal/000337.mp4
# /content/videos/normal/000338.mp4
# /content/videos/normal/000339.mp4
# /content/videos/normal/000340.mp4
# Processed 340 normal videos.
# /content/videos/normal/000341.mp4
# /content/videos/normal/000342.mp4
# /content/videos/normal/000343.mp4
# /content/videos/normal/000344.mp4
# /content/videos/normal/000345.mp4
# /content/videos/normal/000346.mp4
# /content/videos/normal/000347.mp4
# /content/videos/normal/000348.mp4
# /content/videos/normal/000349.mp4
# /content/videos/normal/000350.mp4
# Processed 350 normal videos.
# /content/videos/normal/000351.mp4
# /content/videos/normal/000352.mp4
# /content/videos/normal/000353.mp4
# /content/videos/normal/000354.mp4
# /content/videos/normal/000355.mp4
# /content/videos/normal/000356.mp4
# /content/videos/normal/000357.mp4
# /content/videos/normal/000358.mp4
# /content/videos/normal/000359.mp4
# /content/videos/normal/000360.mp4
# Processed 360 normal videos.
# /content/videos/normal/000361.mp4
# /content/videos/normal/000362.mp4
# /content/videos/normal/000363.mp4
# /content/videos/normal/000364.mp4
# /content/videos/normal/000365.mp4
# /content/videos/normal/000366.mp4
# /content/videos/normal/000367.mp4
# /content/videos/normal/000368.mp4
# /content/videos/normal/000369.mp4
# /content/videos/normal/000370.mp4
# Processed 370 normal videos.
# /content/videos/normal/000371.mp4
# /content/videos/normal/000372.mp4
# /content/videos/normal/000373.mp4
# /content/videos/normal/000374.mp4
# /content/videos/normal/000375.mp4
# /content/videos/normal/000376.mp4
# /content/videos/normal/000377.mp4
# /content/videos/normal/000378.mp4
# /content/videos/normal/000379.mp4
# /content/videos/normal/000380.mp4
# Processed 380 normal videos.
# /content/videos/normal/000381.mp4
# /content/videos/normal/000382.mp4
# /content/videos/normal/000383.mp4
# /content/videos/normal/000384.mp4
# /content/videos/normal/000385.mp4
# /content/videos/normal/000386.mp4
# /content/videos/normal/000387.mp4
# /content/videos/normal/000388.mp4
# /content/videos/normal/000389.mp4
# /content/videos/normal/000390.mp4
# Processed 390 normal videos.
# /content/videos/normal/000391.mp4
# /content/videos/normal/000392.mp4
# /content/videos/normal/000393.mp4
# /content/videos/normal/000394.mp4
# /content/videos/normal/000395.mp4
# /content/videos/normal/000396.mp4
# /content/videos/normal/000397.mp4
# /content/videos/normal/000398.mp4
# /content/videos/normal/000399.mp4
# /content/videos/normal/000400.mp4
# Processed 400 normal videos.
# /content/videos/normal/000401.mp4
# /content/videos/normal/000402.mp4
# /content/videos/normal/000403.mp4
# /content/videos/normal/000404.mp4
# /content/videos/normal/000405.mp4
# /content/videos/normal/000406.mp4
# /content/videos/normal/000407.mp4
# /content/videos/normal/000408.mp4
# /content/videos/normal/000409.mp4
# /content/videos/normal/000410.mp4
# Processed 410 normal videos.
# /content/videos/normal/000411.mp4
# /content/videos/normal/000412.mp4
# /content/videos/normal/000413.mp4
# /content/videos/normal/000414.mp4
# /content/videos/normal/000415.mp4
# /content/videos/normal/000416.mp4
# /content/videos/normal/000417.mp4
# /content/videos/normal/000418.mp4
# /content/videos/normal/000419.mp4
# /content/videos/normal/000420.mp4
# Processed 420 normal videos.
# /content/videos/normal/000421.mp4
# /content/videos/normal/000422.mp4
# /content/videos/normal/000423.mp4
# /content/videos/normal/000424.mp4
# /content/videos/normal/000425.mp4
# /content/videos/normal/000426.mp4
# /content/videos/normal/000427.mp4
# /content/videos/normal/000428.mp4
# /content/videos/normal/000429.mp4
# /content/videos/normal/000430.mp4
# Processed 430 normal videos.
# /content/videos/normal/000431.mp4
# /content/videos/normal/000432.mp4
# /content/videos/normal/000433.mp4
# /content/videos/normal/000434.mp4
# /content/videos/normal/000435.mp4
# /content/videos/normal/000436.mp4
# /content/videos/normal/000437.mp4
# /content/videos/normal/000438.mp4
# /content/videos/normal/000439.mp4
# /content/videos/normal/000440.mp4
# Processed 440 normal videos.
# /content/videos/normal/000441.mp4
# /content/videos/normal/000442.mp4
# /content/videos/normal/000443.mp4
# /content/videos/normal/000444.mp4
# /content/videos/normal/000445.mp4
# /content/videos/normal/000446.mp4
# /content/videos/normal/000447.mp4
# /content/videos/normal/000448.mp4
# /content/videos/normal/000449.mp4
# /content/videos/normal/000450.mp4
# Processed 450 normal videos.
# /content/videos/normal/000451.mp4
# /content/videos/normal/000452.mp4
# /content/videos/normal/000453.mp4
# /content/videos/normal/000454.mp4
# /content/videos/normal/000455.mp4
# /content/videos/normal/000456.mp4
# /content/videos/normal/000457.mp4
# /content/videos/normal/000458.mp4
# /content/videos/normal/000459.mp4
# /content/videos/normal/000460.mp4
# Processed 460 normal videos.
# /content/videos/normal/000461.mp4
# /content/videos/normal/000462.mp4
# /content/videos/normal/000463.mp4
# /content/videos/normal/000464.mp4
# /content/videos/normal/000465.mp4
# /content/videos/normal/000466.mp4
# /content/videos/normal/000467.mp4
# /content/videos/normal/000468.mp4
# /content/videos/normal/000469.mp4
# /content/videos/normal/000470.mp4
# Processed 470 normal videos.
# /content/videos/normal/000471.mp4
# /content/videos/normal/000472.mp4
# /content/videos/normal/000473.mp4
# /content/videos/normal/000474.mp4
# /content/videos/normal/000475.mp4
# /content/videos/normal/000476.mp4
# /content/videos/normal/000477.mp4
# /content/videos/normal/000478.mp4
# /content/videos/normal/000479.mp4
# /content/videos/normal/000480.mp4
# Processed 480 normal videos.
# /content/videos/normal/000481.mp4
# /content/videos/normal/000482.mp4
# /content/videos/normal/000483.mp4
# /content/videos/normal/000484.mp4
# /content/videos/normal/000485.mp4
# /content/videos/normal/000486.mp4
# /content/videos/normal/000487.mp4
# /content/videos/normal/000488.mp4
# /content/videos/normal/000489.mp4
# /content/videos/normal/000490.mp4
# Processed 490 normal videos.
# /content/videos/normal/000491.mp4
# /content/videos/normal/000492.mp4
# /content/videos/normal/000493.mp4
# /content/videos/normal/000494.mp4
# /content/videos/normal/000495.mp4
# /content/videos/normal/000496.mp4
# /content/videos/normal/000497.mp4
# /content/videos/normal/000498.mp4
# /content/videos/normal/000499.mp4
# /content/videos/normal/000500.mp4
# Processed 500 normal videos.
# /content/videos/normal/000501.mp4
# /content/videos/normal/000502.mp4
# /content/videos/normal/000503.mp4
# /content/videos/normal/000504.mp4
# /content/videos/normal/000505.mp4
# /content/videos/normal/000506.mp4
# /content/videos/normal/000507.mp4
# /content/videos/normal/000508.mp4
# /content/videos/normal/000509.mp4
# /content/videos/normal/000510.mp4
# Processed 510 normal videos.
# /content/videos/normal/000511.mp4
# /content/videos/normal/000512.mp4
# /content/videos/normal/000513.mp4
# /content/videos/normal/000514.mp4
# /content/videos/normal/000515.mp4
# /content/videos/normal/000516.mp4
# /content/videos/normal/000517.mp4
# /content/videos/normal/000518.mp4
# /content/videos/normal/000519.mp4
# /content/videos/normal/000520.mp4
# Processed 520 normal videos.
# /content/videos/normal/000521.mp4
# /content/videos/normal/000522.mp4
# /content/videos/normal/000523.mp4
# /content/videos/normal/000524.mp4
# /content/videos/normal/000525.mp4
# /content/videos/normal/000526.mp4
# /content/videos/normal/000527.mp4
# /content/videos/normal/000528.mp4
# /content/videos/normal/000529.mp4
# /content/videos/normal/000530.mp4
# Processed 530 normal videos.
# /content/videos/normal/000531.mp4
# /content/videos/normal/000532.mp4
# /content/videos/normal/000533.mp4
# /content/videos/normal/000534.mp4
# /content/videos/normal/000535.mp4
# /content/videos/normal/000536.mp4
# /content/videos/normal/000537.mp4
# /content/videos/normal/000538.mp4
# /content/videos/normal/000539.mp4
# /content/videos/normal/000540.mp4
# Processed 540 normal videos.
# /content/videos/normal/000541.mp4
# /content/videos/normal/000542.mp4
# /content/videos/normal/000543.mp4
# /content/videos/normal/000544.mp4
# /content/videos/normal/000545.mp4
# /content/videos/normal/000546.mp4
# /content/videos/normal/000547.mp4
# /content/videos/normal/000548.mp4
# /content/videos/normal/000549.mp4
# /content/videos/normal/000550.mp4
# Processed 550 normal videos.
# /content/videos/normal/000551.mp4
# /content/videos/normal/000552.mp4
# /content/videos/normal/000553.mp4
# /content/videos/normal/000554.mp4
# /content/videos/normal/000555.mp4
# /content/videos/normal/000556.mp4
# /content/videos/normal/000557.mp4
# /content/videos/normal/000558.mp4
# /content/videos/normal/000559.mp4
# /content/videos/normal/000560.mp4
# Processed 560 normal videos.
# /content/videos/normal/000561.mp4
# /content/videos/normal/000562.mp4
# /content/videos/normal/000563.mp4
# /content/videos/normal/000564.mp4
# /content/videos/normal/000565.mp4
# /content/videos/normal/000566.mp4
# /content/videos/normal/000567.mp4
# /content/videos/normal/000568.mp4
# /content/videos/normal/000569.mp4
# /content/videos/normal/000570.mp4
# Processed 570 normal videos.
# /content/videos/normal/000571.mp4
# /content/videos/normal/000572.mp4
# /content/videos/normal/000573.mp4
# /content/videos/normal/000574.mp4
# /content/videos/normal/000575.mp4
# /content/videos/normal/000576.mp4
# /content/videos/normal/000577.mp4
# /content/videos/normal/000578.mp4
# /content/videos/normal/000579.mp4
# /content/videos/normal/000580.mp4
# Processed 580 normal videos.
# /content/videos/normal/000581.mp4
# /content/videos/normal/000582.mp4
# /content/videos/normal/000583.mp4
# /content/videos/normal/000584.mp4
# /content/videos/normal/000585.mp4
# /content/videos/normal/000586.mp4
# /content/videos/normal/000587.mp4
# /content/videos/normal/000588.mp4
# /content/videos/normal/000589.mp4
# /content/videos/normal/000590.mp4
# Processed 590 normal videos.
# /content/videos/normal/000591.mp4
# /content/videos/normal/000592.mp4
# /content/videos/normal/000593.mp4
# /content/videos/normal/000594.mp4
# /content/videos/normal/000595.mp4
# /content/videos/normal/000596.mp4
# /content/videos/normal/000597.mp4
# /content/videos/normal/000598.mp4
# /content/videos/normal/000599.mp4
# /content/videos/normal/000600.mp4
# Processed 600 normal videos.
# /content/videos/normal/000601.mp4
# /content/videos/normal/000602.mp4
# /content/videos/normal/000603.mp4
# /content/videos/normal/000604.mp4
# /content/videos/normal/000605.mp4
# /content/videos/normal/000606.mp4
# /content/videos/normal/000607.mp4
# /content/videos/normal/000608.mp4
# /content/videos/normal/000609.mp4
# /content/videos/normal/000610.mp4
# Processed 610 normal videos.
# /content/videos/normal/000611.mp4
# /content/videos/normal/000612.mp4
# /content/videos/normal/000613.mp4
# /content/videos/normal/000614.mp4
# /content/videos/normal/000615.mp4
# /content/videos/normal/000616.mp4
# /content/videos/normal/000617.mp4
# /content/videos/normal/000618.mp4
# /content/videos/normal/000619.mp4
# /content/videos/normal/000620.mp4
# Processed 620 normal videos.
# /content/videos/normal/000621.mp4
# /content/videos/normal/000622.mp4
# /content/videos/normal/000623.mp4
# /content/videos/normal/000624.mp4
# /content/videos/normal/000625.mp4
# /content/videos/normal/000626.mp4
# /content/videos/normal/000627.mp4
# /content/videos/normal/000628.mp4
# /content/videos/normal/000629.mp4
# /content/videos/normal/000630.mp4
# Processed 630 normal videos.
# /content/videos/normal/000631.mp4
# /content/videos/normal/000632.mp4
# /content/videos/normal/000633.mp4
# /content/videos/normal/000634.mp4
# /content/videos/normal/000635.mp4
# /content/videos/normal/000636.mp4
# /content/videos/normal/000637.mp4
# /content/videos/normal/000638.mp4
# /content/videos/normal/000639.mp4
# /content/videos/normal/000640.mp4
# Processed 640 normal videos.
# /content/videos/normal/000641.mp4
# /content/videos/normal/000642.mp4
# /content/videos/normal/000643.mp4
# /content/videos/normal/000644.mp4
# /content/videos/normal/000645.mp4
# /content/videos/normal/000646.mp4
# /content/videos/normal/000647.mp4
# /content/videos/normal/000648.mp4
# /content/videos/normal/000649.mp4
# /content/videos/normal/000650.mp4
# Processed 650 normal videos.
# /content/videos/normal/000651.mp4
# /content/videos/normal/000652.mp4
# /content/videos/normal/000653.mp4
# /content/videos/normal/000654.mp4
# /content/videos/normal/000655.mp4
# /content/videos/normal/000656.mp4
# /content/videos/normal/000657.mp4
# /content/videos/normal/000658.mp4
# /content/videos/normal/000659.mp4
# /content/videos/normal/000660.mp4
# Processed 660 normal videos.
# /content/videos/normal/000661.mp4
# /content/videos/normal/000662.mp4
# /content/videos/normal/000663.mp4
# /content/videos/normal/000664.mp4
# /content/videos/normal/000665.mp4
# /content/videos/normal/000666.mp4
# /content/videos/normal/000667.mp4
# /content/videos/normal/000668.mp4
# /content/videos/normal/000669.mp4
# /content/videos/normal/000670.mp4
# Processed 670 normal videos.
# /content/videos/normal/000671.mp4
# /content/videos/normal/000672.mp4
# /content/videos/normal/000673.mp4
# /content/videos/normal/000674.mp4
# /content/videos/normal/000675.mp4
# /content/videos/normal/000676.mp4
# /content/videos/normal/000677.mp4
# /content/videos/normal/000678.mp4
# /content/videos/normal/000679.mp4
# /content/videos/normal/000680.mp4
# Processed 680 normal videos.
# /content/videos/normal/000681.mp4
# /content/videos/normal/000682.mp4
# /content/videos/normal/000683.mp4
# /content/videos/normal/000684.mp4
# /content/videos/normal/000685.mp4
# /content/videos/normal/000686.mp4
# /content/videos/normal/000687.mp4
# /content/videos/normal/000688.mp4
# /content/videos/normal/000689.mp4
# /content/videos/normal/000690.mp4
# Processed 690 normal videos.
# /content/videos/normal/000691.mp4
# /content/videos/normal/000692.mp4
# /content/videos/normal/000693.mp4
# /content/videos/normal/000694.mp4
# /content/videos/normal/000695.mp4
# /content/videos/normal/000696.mp4
# /content/videos/normal/000697.mp4
# /content/videos/normal/000698.mp4
# /content/videos/normal/000699.mp4
# /content/videos/normal/000700.mp4
# Processed 700 normal videos.
# /content/videos/normal/000701.mp4
# /content/videos/normal/000702.mp4
# /content/videos/normal/000703.mp4
# /content/videos/normal/000704.mp4
# /content/videos/normal/000705.mp4
# /content/videos/normal/000706.mp4
# /content/videos/normal/000707.mp4
# /content/videos/normal/000708.mp4
# /content/videos/normal/000709.mp4
# /content/videos/normal/000710.mp4
# Processed 710 normal videos.
# /content/videos/normal/000711.mp4
# /content/videos/normal/000712.mp4
# /content/videos/normal/000713.mp4
# /content/videos/normal/000714.mp4
# /content/videos/normal/000715.mp4
# /content/videos/normal/000716.mp4
# /content/videos/normal/000717.mp4
# /content/videos/normal/000718.mp4
# /content/videos/normal/000719.mp4
# /content/videos/normal/000720.mp4
# Processed 720 normal videos.
# /content/videos/normal/000721.mp4
# /content/videos/normal/000722.mp4
# /content/videos/normal/000723.mp4
# /content/videos/normal/000724.mp4
# /content/videos/normal/000725.mp4
# /content/videos/normal/000726.mp4
# /content/videos/normal/000727.mp4
# /content/videos/normal/000728.mp4
# /content/videos/normal/000729.mp4
# /content/videos/normal/000730.mp4
# Processed 730 normal videos.
# /content/videos/normal/000731.mp4
# /content/videos/normal/000732.mp4
# /content/videos/normal/000733.mp4
# /content/videos/normal/000734.mp4
# /content/videos/normal/000735.mp4
# /content/videos/normal/000736.mp4
# /content/videos/normal/000737.mp4
# /content/videos/normal/000738.mp4
# /content/videos/normal/000739.mp4
# /content/videos/normal/000740.mp4
# Processed 740 normal videos.
# /content/videos/normal/000741.mp4
# /content/videos/normal/000742.mp4
# /content/videos/normal/000743.mp4
# /content/videos/normal/000744.mp4
# /content/videos/normal/000745.mp4
# /content/videos/normal/000746.mp4
# /content/videos/normal/000747.mp4
# /content/videos/normal/000748.mp4
# /content/videos/normal/000749.mp4
# /content/videos/normal/000750.mp4
# Processed 750 normal videos.
# /content/videos/normal/000751.mp4
# /content/videos/normal/000752.mp4
# /content/videos/normal/000753.mp4
# /content/videos/normal/000754.mp4
# /content/videos/normal/000755.mp4
# /content/videos/normal/000756.mp4
# /content/videos/normal/000757.mp4
# /content/videos/normal/000758.mp4
# /content/videos/normal/000759.mp4
# /content/videos/normal/000760.mp4
# Processed 760 normal videos.
# /content/videos/normal/000761.mp4
# /content/videos/normal/000762.mp4
# /content/videos/normal/000763.mp4
# /content/videos/normal/000764.mp4
# /content/videos/normal/000765.mp4
# /content/videos/normal/000766.mp4
# /content/videos/normal/000767.mp4
# /content/videos/normal/000768.mp4
# /content/videos/normal/000769.mp4
# /content/videos/normal/000770.mp4
# Processed 770 normal videos.
# /content/videos/normal/000771.mp4
# /content/videos/normal/000772.mp4
# /content/videos/normal/000773.mp4
# /content/videos/normal/000774.mp4
# /content/videos/normal/000775.mp4
# /content/videos/normal/000776.mp4
# /content/videos/normal/000777.mp4
# /content/videos/normal/000778.mp4
# /content/videos/normal/000779.mp4
# /content/videos/normal/000780.mp4
# Processed 780 normal videos.
# /content/videos/normal/000781.mp4
# /content/videos/normal/000782.mp4
# /content/videos/normal/000783.mp4
# /content/videos/normal/000784.mp4
# /content/videos/normal/000785.mp4
# /content/videos/normal/000786.mp4
# /content/videos/normal/000787.mp4
# /content/videos/normal/000788.mp4
# /content/videos/normal/000789.mp4
# /content/videos/normal/000790.mp4
# Processed 790 normal videos.
# /content/videos/normal/000791.mp4
# /content/videos/normal/000792.mp4
# /content/videos/normal/000793.mp4
# /content/videos/normal/000794.mp4
# /content/videos/normal/000795.mp4
# /content/videos/normal/000796.mp4
# /content/videos/normal/000797.mp4
# /content/videos/normal/000798.mp4
# /content/videos/normal/000799.mp4
# /content/videos/normal/000800.mp4
# Processed 800 normal videos.
# /content/videos/normal/000801.mp4
# /content/videos/normal/000802.mp4
# /content/videos/normal/000803.mp4
# /content/videos/normal/000804.mp4
# /content/videos/normal/000805.mp4
# /content/videos/normal/000806.mp4
# /content/videos/normal/000807.mp4
# /content/videos/normal/000808.mp4
# /content/videos/normal/000809.mp4
# /content/videos/normal/000810.mp4
# Processed 810 normal videos.
# /content/videos/normal/000811.mp4
# /content/videos/normal/000812.mp4
# /content/videos/normal/000813.mp4
# /content/videos/normal/000814.mp4
# /content/videos/normal/000815.mp4
# /content/videos/normal/000816.mp4
# /content/videos/normal/000817.mp4
# /content/videos/normal/000818.mp4
# /content/videos/normal/000819.mp4
# /content/videos/normal/000820.mp4
# Processed 820 normal videos.
# /content/videos/normal/000821.mp4
# /content/videos/normal/000822.mp4
# /content/videos/normal/000823.mp4
# /content/videos/normal/000824.mp4
# /content/videos/normal/000825.mp4
# /content/videos/normal/000826.mp4
# /content/videos/normal/000827.mp4
# /content/videos/normal/000828.mp4
# /content/videos/normal/000829.mp4
# /content/videos/normal/000830.mp4
# Processed 830 normal videos.
# /content/videos/normal/000831.mp4
# /content/videos/normal/000832.mp4
# /content/videos/normal/000833.mp4
# /content/videos/normal/000834.mp4
# /content/videos/normal/000835.mp4
# /content/videos/normal/000836.mp4
# /content/videos/normal/000837.mp4
# /content/videos/normal/000838.mp4
# /content/videos/normal/000839.mp4
# /content/videos/normal/000840.mp4
# Processed 840 normal videos.
# /content/videos/normal/000841.mp4
# /content/videos/normal/000842.mp4
# /content/videos/normal/000843.mp4
# /content/videos/normal/000844.mp4
# /content/videos/normal/000845.mp4
# /content/videos/normal/000846.mp4
# /content/videos/normal/000847.mp4
# /content/videos/normal/000848.mp4
# /content/videos/normal/000849.mp4
# /content/videos/normal/000850.mp4
# Processed 850 normal videos.
# /content/videos/normal/000851.mp4
# /content/videos/normal/000852.mp4
# /content/videos/normal/000853.mp4
# /content/videos/normal/000854.mp4
# /content/videos/normal/000855.mp4
# /content/videos/normal/000856.mp4
# /content/videos/normal/000857.mp4
# /content/videos/normal/000858.mp4
# /content/videos/normal/000859.mp4
# /content/videos/normal/000860.mp4
# Processed 860 normal videos.
# /content/videos/normal/000861.mp4
# /content/videos/normal/000862.mp4
# /content/videos/normal/000863.mp4
# /content/videos/normal/000864.mp4
# /content/videos/normal/000865.mp4
# /content/videos/normal/000866.mp4
# /content/videos/normal/000867.mp4
# /content/videos/normal/000868.mp4
# /content/videos/normal/000869.mp4
# /content/videos/normal/000870.mp4
# Processed 870 normal videos.
# /content/videos/normal/000871.mp4
# /content/videos/normal/000872.mp4
# /content/videos/normal/000873.mp4
# /content/videos/normal/000874.mp4
# /content/videos/normal/000875.mp4
# /content/videos/normal/000876.mp4
# /content/videos/normal/000877.mp4
# /content/videos/normal/000878.mp4
# /content/videos/normal/000879.mp4
# /content/videos/normal/000880.mp4
# Processed 880 normal videos.
# /content/videos/normal/000881.mp4
# /content/videos/normal/000882.mp4
# /content/videos/normal/000883.mp4
# /content/videos/normal/000884.mp4
# /content/videos/normal/000885.mp4
# /content/videos/normal/000886.mp4
# /content/videos/normal/000887.mp4
# /content/videos/normal/000888.mp4
# /content/videos/normal/000889.mp4
# /content/videos/normal/000890.mp4
# Processed 890 normal videos.
# /content/videos/normal/000891.mp4
# /content/videos/normal/000892.mp4
# /content/videos/normal/000893.mp4
# /content/videos/normal/000894.mp4
# /content/videos/normal/000895.mp4
# /content/videos/normal/000896.mp4
# /content/videos/normal/000897.mp4
# /content/videos/normal/000898.mp4
# /content/videos/normal/000899.mp4
# /content/videos/normal/000900.mp4
# Processed 900 normal videos.
# /content/videos/normal/000901.mp4
# /content/videos/normal/000902.mp4
# /content/videos/normal/000903.mp4
# /content/videos/normal/000904.mp4
# /content/videos/normal/000905.mp4
# /content/videos/normal/000906.mp4
# /content/videos/normal/000907.mp4
# /content/videos/normal/000908.mp4
# /content/videos/normal/000909.mp4
# /content/videos/normal/000910.mp4
# Processed 910 normal videos.
# /content/videos/normal/000911.mp4
# /content/videos/normal/000912.mp4
# /content/videos/normal/000913.mp4
# /content/videos/normal/000914.mp4
# /content/videos/normal/000915.mp4
# /content/videos/normal/000916.mp4
# /content/videos/normal/000917.mp4
# /content/videos/normal/000918.mp4
# /content/videos/normal/000919.mp4
# /content/videos/normal/000920.mp4
# Processed 920 normal videos.
# /content/videos/normal/000921.mp4
# /content/videos/normal/000922.mp4
# /content/videos/normal/000923.mp4
# /content/videos/normal/000924.mp4
# /content/videos/normal/000925.mp4
# /content/videos/normal/000926.mp4
# /content/videos/normal/000927.mp4
# /content/videos/normal/000928.mp4
# /content/videos/normal/000929.mp4
# /content/videos/normal/000930.mp4
# Processed 930 normal videos.
# /content/videos/normal/000931.mp4
# /content/videos/normal/000932.mp4
# /content/videos/normal/000933.mp4
# /content/videos/normal/000934.mp4
# /content/videos/normal/000935.mp4
# /content/videos/normal/000936.mp4
# /content/videos/normal/000937.mp4
# /content/videos/normal/000938.mp4
# /content/videos/normal/000939.mp4
# /content/videos/normal/000940.mp4
# Processed 940 normal videos.
# /content/videos/normal/000941.mp4
# /content/videos/normal/000942.mp4
# /content/videos/normal/000943.mp4
# /content/videos/normal/000944.mp4
# /content/videos/normal/000945.mp4
# /content/videos/normal/000946.mp4
# /content/videos/normal/000947.mp4
# /content/videos/normal/000948.mp4
# /content/videos/normal/000949.mp4
# /content/videos/normal/000950.mp4
# Processed 950 normal videos.
# /content/videos/normal/000951.mp4
# /content/videos/normal/000952.mp4
# /content/videos/normal/000953.mp4
# /content/videos/normal/000954.mp4
# /content/videos/normal/000955.mp4
# /content/videos/normal/000956.mp4
# /content/videos/normal/000957.mp4
# /content/videos/normal/000958.mp4
# /content/videos/normal/000959.mp4
# /content/videos/normal/000960.mp4
# Processed 960 normal videos.
# /content/videos/normal/000961.mp4
# /content/videos/normal/000962.mp4
# /content/videos/normal/000963.mp4
# /content/videos/normal/000964.mp4
# /content/videos/normal/000965.mp4
# /content/videos/normal/000966.mp4
# /content/videos/normal/000967.mp4
# /content/videos/normal/000968.mp4
# /content/videos/normal/000969.mp4
# /content/videos/normal/000970.mp4
# Processed 970 normal videos.
# /content/videos/normal/000971.mp4
# /content/videos/normal/000972.mp4
# /content/videos/normal/000973.mp4
# /content/videos/normal/000974.mp4
# /content/videos/normal/000975.mp4
# /content/videos/normal/000976.mp4
# /content/videos/normal/000977.mp4
# /content/videos/normal/000978.mp4
# /content/videos/normal/000979.mp4
# /content/videos/normal/000980.mp4
# Processed 980 normal videos.
# /content/videos/normal/000981.mp4
# /content/videos/normal/000982.mp4
# /content/videos/normal/000983.mp4
# /content/videos/normal/000984.mp4
# /content/videos/normal/000985.mp4
# /content/videos/normal/000986.mp4
# /content/videos/normal/000987.mp4
# /content/videos/normal/000988.mp4
# /content/videos/normal/000989.mp4
# /content/videos/normal/000990.mp4
# Processed 990 normal videos.
# /content/videos/normal/000991.mp4
# /content/videos/normal/000992.mp4
# /content/videos/normal/000993.mp4
# /content/videos/normal/000994.mp4
# /content/videos/normal/000995.mp4
# /content/videos/normal/000996.mp4
# /content/videos/normal/000997.mp4
# /content/videos/normal/000998.mp4
# /content/videos/normal/000999.mp4
# /content/videos/normal/001000.mp4
# Processed 1000 normal videos.
# /content/videos/normal/001001.mp4
# /content/videos/normal/001002.mp4
# /content/videos/normal/001003.mp4
# /content/videos/normal/001004.mp4
# /content/videos/normal/001005.mp4
# /content/videos/normal/001006.mp4
# /content/videos/normal/001007.mp4
# /content/videos/normal/001008.mp4
# /content/videos/normal/001009.mp4
# /content/videos/normal/001010.mp4
# Processed 1010 normal videos.
# /content/videos/normal/001011.mp4
# /content/videos/normal/001012.mp4
# /content/videos/normal/001013.mp4
# /content/videos/normal/001014.mp4
# /content/videos/normal/001015.mp4
# /content/videos/normal/001016.mp4
# /content/videos/normal/001017.mp4
# /content/videos/normal/001018.mp4
# /content/videos/normal/001019.mp4
# /content/videos/normal/001020.mp4
# Processed 1020 normal videos.
# /content/videos/normal/001021.mp4
# /content/videos/normal/001022.mp4
# /content/videos/normal/001023.mp4
# /content/videos/normal/001024.mp4
# /content/videos/normal/001025.mp4
# /content/videos/normal/001026.mp4
# /content/videos/normal/001027.mp4
# /content/videos/normal/001028.mp4
# /content/videos/normal/001029.mp4
# /content/videos/normal/001030.mp4
# Processed 1030 normal videos.
# /content/videos/normal/001031.mp4
# /content/videos/normal/001032.mp4
# /content/videos/normal/001033.mp4
# /content/videos/normal/001034.mp4
# /content/videos/normal/001035.mp4
# /content/videos/normal/001036.mp4
# /content/videos/normal/001037.mp4
# /content/videos/normal/001038.mp4
# /content/videos/normal/001039.mp4
# /content/videos/normal/001040.mp4
# Processed 1040 normal videos.
# /content/videos/normal/001041.mp4
# /content/videos/normal/001042.mp4
# /content/videos/normal/001043.mp4
# /content/videos/normal/001044.mp4
# /content/videos/normal/001045.mp4
# /content/videos/normal/001046.mp4
# /content/videos/normal/001047.mp4
# /content/videos/normal/001048.mp4
# /content/videos/normal/001049.mp4
# /content/videos/normal/001050.mp4
# Processed 1050 normal videos.
# /content/videos/normal/001051.mp4
# /content/videos/normal/001052.mp4
# /content/videos/normal/001053.mp4
# /content/videos/normal/001054.mp4
# /content/videos/normal/001055.mp4
# /content/videos/normal/001056.mp4
# /content/videos/normal/001057.mp4
# /content/videos/normal/001058.mp4
# /content/videos/normal/001059.mp4
# /content/videos/normal/001060.mp4
# Processed 1060 normal videos.
# /content/videos/normal/001061.mp4
# /content/videos/normal/001062.mp4
# /content/videos/normal/001063.mp4
# /content/videos/normal/001064.mp4
# /content/videos/normal/001065.mp4
# /content/videos/normal/001066.mp4
# /content/videos/normal/001067.mp4
# /content/videos/normal/001068.mp4
# /content/videos/normal/001069.mp4
# /content/videos/normal/001070.mp4
# Processed 1070 normal videos.
# /content/videos/normal/001071.mp4
# /content/videos/normal/001072.mp4
# /content/videos/normal/001073.mp4
# /content/videos/normal/001074.mp4
# /content/videos/normal/001075.mp4
# /content/videos/normal/001076.mp4
# /content/videos/normal/001077.mp4
# /content/videos/normal/001078.mp4
# /content/videos/normal/001079.mp4
# /content/videos/normal/001080.mp4
# Processed 1080 normal videos.
# /content/videos/normal/001081.mp4
# /content/videos/normal/001082.mp4
# /content/videos/normal/001083.mp4
# /content/videos/normal/001084.mp4
# /content/videos/normal/001085.mp4
# /content/videos/normal/001086.mp4
# /content/videos/normal/001087.mp4
# /content/videos/normal/001088.mp4
# /content/videos/normal/001089.mp4
# /content/videos/normal/001090.mp4
# Processed 1090 normal videos.
# /content/videos/normal/001091.mp4
# /content/videos/normal/001092.mp4
# /content/videos/normal/001093.mp4
# /content/videos/normal/001094.mp4
# /content/videos/normal/001095.mp4
# /content/videos/normal/001096.mp4
# /content/videos/normal/001097.mp4
# /content/videos/normal/001098.mp4
# /content/videos/normal/001099.mp4
# /content/videos/normal/001100.mp4
# Processed 1100 normal videos.
# /content/videos/normal/001101.mp4
# /content/videos/normal/001102.mp4
# /content/videos/normal/001103.mp4
# /content/videos/normal/001104.mp4
# /content/videos/normal/001105.mp4
# /content/videos/normal/001106.mp4
# /content/videos/normal/001107.mp4
# /content/videos/normal/001108.mp4
# /content/videos/normal/001109.mp4
# /content/videos/normal/001110.mp4
# Processed 1110 normal videos.
# /content/videos/normal/001111.mp4
# /content/videos/normal/001112.mp4
# /content/videos/normal/001113.mp4
# /content/videos/normal/001114.mp4
# /content/videos/normal/001115.mp4
# /content/videos/normal/001116.mp4
# /content/videos/normal/001117.mp4
# /content/videos/normal/001118.mp4
# /content/videos/normal/001119.mp4
# /content/videos/normal/001120.mp4
# Processed 1120 normal videos.
# /content/videos/normal/001121.mp4
# /content/videos/normal/001122.mp4
# /content/videos/normal/001123.mp4
# /content/videos/normal/001124.mp4
# /content/videos/normal/001125.mp4
# /content/videos/normal/001126.mp4
# /content/videos/normal/001127.mp4
# /content/videos/normal/001128.mp4
# /content/videos/normal/001129.mp4
# /content/videos/normal/001130.mp4
# Processed 1130 normal videos.
# /content/videos/normal/001131.mp4
# /content/videos/normal/001132.mp4
# /content/videos/normal/001133.mp4
# /content/videos/normal/001134.mp4
# /content/videos/normal/001135.mp4
# /content/videos/normal/001136.mp4
# /content/videos/normal/001137.mp4
# /content/videos/normal/001138.mp4
# /content/videos/normal/001139.mp4
# /content/videos/normal/001140.mp4
# Processed 1140 normal videos.
# /content/videos/normal/001141.mp4
# /content/videos/normal/001142.mp4
# /content/videos/normal/001143.mp4
# /content/videos/normal/001144.mp4
# /content/videos/normal/001145.mp4
# /content/videos/normal/001146.mp4
# /content/videos/normal/001147.mp4
# /content/videos/normal/001148.mp4
# /content/videos/normal/001149.mp4
# /content/videos/normal/001150.mp4
# Processed 1150 normal videos.
# /content/videos/normal/001151.mp4
# /content/videos/normal/001152.mp4
# /content/videos/normal/001153.mp4
# /content/videos/normal/001154.mp4
# /content/videos/normal/001155.mp4
# /content/videos/normal/001156.mp4
# /content/videos/normal/001157.mp4
# /content/videos/normal/001158.mp4
# /content/videos/normal/001159.mp4
# /content/videos/normal/001160.mp4
# Processed 1160 normal videos.
# /content/videos/normal/001161.mp4
# /content/videos/normal/001162.mp4
# /content/videos/normal/001163.mp4
# /content/videos/normal/001164.mp4
# /content/videos/normal/001165.mp4
# /content/videos/normal/001166.mp4
# /content/videos/normal/001167.mp4
# /content/videos/normal/001168.mp4
# /content/videos/normal/001169.mp4
# /content/videos/normal/001170.mp4
# Processed 1170 normal videos.
# /content/videos/normal/001171.mp4
# /content/videos/normal/001172.mp4
# /content/videos/normal/001173.mp4
# /content/videos/normal/001174.mp4
# /content/videos/normal/001175.mp4
# /content/videos/normal/001176.mp4
# /content/videos/normal/001177.mp4
# /content/videos/normal/001178.mp4
# /content/videos/normal/001179.mp4
# /content/videos/normal/001180.mp4
# Processed 1180 normal videos.
# /content/videos/normal/001181.mp4
# /content/videos/normal/001182.mp4
# /content/videos/normal/001183.mp4
# /content/videos/normal/001184.mp4
# /content/videos/normal/001185.mp4
# /content/videos/normal/001186.mp4
# /content/videos/normal/001187.mp4
# /content/videos/normal/001188.mp4
# /content/videos/normal/001189.mp4
# /content/videos/normal/001190.mp4
# Processed 1190 normal videos.
# /content/videos/normal/001191.mp4
# /content/videos/normal/001192.mp4
# /content/videos/normal/001193.mp4
# /content/videos/normal/001194.mp4
# /content/videos/normal/001195.mp4
# /content/videos/normal/001196.mp4
# /content/videos/normal/001197.mp4
# /content/videos/normal/001198.mp4
# /content/videos/normal/001199.mp4
# /content/videos/normal/001200.mp4
# Processed 1200 normal videos.
# /content/videos/normal/001201.mp4
# /content/videos/normal/001202.mp4
# /content/videos/normal/001203.mp4
# /content/videos/normal/001204.mp4
# /content/videos/normal/001205.mp4
# /content/videos/normal/001206.mp4
# /content/videos/normal/001207.mp4
# /content/videos/normal/001208.mp4
# /content/videos/normal/001209.mp4
# /content/videos/normal/001210.mp4
# Processed 1210 normal videos.
# /content/videos/normal/001211.mp4
# /content/videos/normal/001212.mp4
# /content/videos/normal/001213.mp4
# /content/videos/normal/001214.mp4
# /content/videos/normal/001215.mp4
# /content/videos/normal/001216.mp4
# /content/videos/normal/001217.mp4
# /content/videos/normal/001218.mp4
# /content/videos/normal/001219.mp4
# /content/videos/normal/001220.mp4
# Processed 1220 normal videos.
# /content/videos/normal/001221.mp4
# /content/videos/normal/001222.mp4
# /content/videos/normal/001223.mp4
# /content/videos/normal/001224.mp4
# /content/videos/normal/001225.mp4
# /content/videos/normal/001226.mp4
# /content/videos/normal/001227.mp4
# /content/videos/normal/001228.mp4
# /content/videos/normal/001229.mp4
# /content/videos/normal/001230.mp4
# Processed 1230 normal videos.
# /content/videos/normal/001231.mp4
# /content/videos/normal/001232.mp4
# /content/videos/normal/001233.mp4
# /content/videos/normal/001234.mp4
# /content/videos/normal/001235.mp4
# /content/videos/normal/001236.mp4
# /content/videos/normal/001237.mp4
# /content/videos/normal/001238.mp4
# /content/videos/normal/001239.mp4
# /content/videos/normal/001240.mp4
# Processed 1240 normal videos.
# /content/videos/normal/001241.mp4
# /content/videos/normal/001242.mp4
# /content/videos/normal/001243.mp4
# /content/videos/normal/001244.mp4
# /content/videos/normal/001245.mp4
# /content/videos/normal/001246.mp4
# /content/videos/normal/001247.mp4
# /content/videos/normal/001248.mp4
# /content/videos/normal/001249.mp4
# /content/videos/normal/001250.mp4
# Processed 1250 normal videos.
# /content/videos/normal/001251.mp4
# /content/videos/normal/001252.mp4
# /content/videos/normal/001253.mp4
# /content/videos/normal/001254.mp4
# /content/videos/normal/001255.mp4
# /content/videos/normal/001256.mp4
# /content/videos/normal/001257.mp4
# /content/videos/normal/001258.mp4
# /content/videos/normal/001259.mp4
# /content/videos/normal/001260.mp4
# Processed 1260 normal videos.
# /content/videos/normal/001261.mp4
# /content/videos/normal/001262.mp4
# /content/videos/normal/001263.mp4
# /content/videos/normal/001264.mp4
# /content/videos/normal/001265.mp4
# /content/videos/normal/001266.mp4
# /content/videos/normal/001267.mp4
# /content/videos/normal/001268.mp4
# /content/videos/normal/001269.mp4
# /content/videos/normal/001270.mp4
# Processed 1270 normal videos.
# /content/videos/normal/001271.mp4
# /content/videos/normal/001272.mp4
# /content/videos/normal/001273.mp4
# /content/videos/normal/001274.mp4
# /content/videos/normal/001275.mp4
# /content/videos/normal/001276.mp4
# /content/videos/normal/001277.mp4
# /content/videos/normal/001278.mp4
# /content/videos/normal/001279.mp4
# /content/videos/normal/001280.mp4
# Processed 1280 normal videos.
# /content/videos/normal/001281.mp4
# /content/videos/normal/001282.mp4
# /content/videos/normal/001283.mp4
# /content/videos/normal/001284.mp4
# /content/videos/normal/001285.mp4
# /content/videos/normal/001286.mp4
# /content/videos/normal/001287.mp4
# /content/videos/normal/001288.mp4
# /content/videos/normal/001289.mp4
# /content/videos/normal/001290.mp4
# Processed 1290 normal videos.
# /content/videos/normal/001291.mp4
# /content/videos/normal/001292.mp4
# /content/videos/normal/001293.mp4
# /content/videos/normal/001294.mp4
# /content/videos/normal/001295.mp4
# /content/videos/normal/001296.mp4
# /content/videos/normal/001297.mp4
# /content/videos/normal/001298.mp4
# /content/videos/normal/001299.mp4
# /content/videos/normal/001300.mp4
# Processed 1300 normal videos.
# ...
# /content/videos/normal/002570.mp4
# Processed 2570 normal videos.
# /content/videos/normal/002571.mp4
# /content/videos/normal/002572.mp4
# /content/videos/normal/002573.mp4
# /content/videos/normal/002574.mp4
# /content/videos/normal/002575.mp4
# /content/videos/normal/002576.mp4
# /content/videos/normal/002577.mp4
# /content/videos/normal/002578.mp4
# /content/videos/normal/002579.mp4
# /content/videos/normal/002580.mp4
# Processed 2580 normal videos.
# /content/videos/normal/002581.mp4
# /content/videos/normal/002582.mp4
# /content/videos/normal/002583.mp4
# /content/videos/normal/002584.mp4
# /content/videos/normal/002585.mp4
# /content/videos/normal/002586.mp4
# /content/videos/normal/002587.mp4
# /content/videos/normal/002588.mp4
# /content/videos/normal/002589.mp4
# /content/videos/normal/002590.mp4
# Processed 2590 normal videos.
# /content/videos/normal/002591.mp4
# /content/videos/normal/002592.mp4
# /content/videos/normal/002593.mp4
# /content/videos/normal/002594.mp4
# /content/videos/normal/002595.mp4
# /content/videos/normal/002596.mp4
# /content/videos/normal/002597.mp4
# /content/videos/normal/002598.mp4
# /content/videos/normal/002599.mp4
# /content/videos/normal/002600.mp4
# Processed 2600 normal videos.
# /content/videos/normal/002601.mp4
# /content/videos/normal/002602.mp4
# /content/videos/normal/002603.mp4
# /content/videos/normal/002604.mp4
# /content/videos/normal/002605.mp4
# /content/videos/normal/002606.mp4
# /content/videos/normal/002607.mp4
# /content/videos/normal/002608.mp4
# /content/videos/normal/002609.mp4
# /content/videos/normal/002610.mp4
# Processed 2610 normal videos.
# /content/videos/normal/002611.mp4
# /content/videos/normal/002612.mp4
# /content/videos/normal/002613.mp4
# /content/videos/normal/002614.mp4
# /content/videos/normal/002615.mp4
# /content/videos/normal/002616.mp4
# /content/videos/normal/002617.mp4
# /content/videos/normal/002618.mp4
# /content/videos/normal/002619.mp4
# /content/videos/normal/002620.mp4
# Processed 2620 normal videos.
# /content/videos/normal/002621.mp4
# /content/videos/normal/002622.mp4
# /content/videos/normal/002623.mp4
# /content/videos/normal/002624.mp4
# /content/videos/normal/002625.mp4
# /content/videos/normal/002626.mp4
# /content/videos/normal/002627.mp4
# /content/videos/normal/002628.mp4
# /content/videos/normal/002629.mp4
# /content/videos/normal/002630.mp4
# Processed 2630 normal videos.
# /content/videos/normal/002631.mp4
# /content/videos/normal/002632.mp4
# /content/videos/normal/002633.mp4
# /content/videos/normal/002634.mp4
# /content/videos/normal/002635.mp4
# /content/videos/normal/002636.mp4
# /content/videos/normal/002637.mp4
# /content/videos/normal/002638.mp4
# /content/videos/normal/002639.mp4
# /content/videos/normal/002640.mp4
# Processed 2640 normal videos.
# /content/videos/normal/002641.mp4
# /content/videos/normal/002642.mp4
# /content/videos/normal/002643.mp4
# /content/videos/normal/002644.mp4
# /content/videos/normal/002645.mp4
# /content/videos/normal/002646.mp4
# /content/videos/normal/002647.mp4
# /content/videos/normal/002648.mp4
# /content/videos/normal/002649.mp4
# /content/videos/normal/002650.mp4
# Processed 2650 normal videos.
# /content/videos/normal/002651.mp4
# /content/videos/normal/002652.mp4
# /content/videos/normal/002653.mp4
# /content/videos/normal/002654.mp4
# /content/videos/normal/002655.mp4
# /content/videos/normal/002656.mp4
# /content/videos/normal/002657.mp4
# /content/videos/normal/002658.mp4
# /content/videos/normal/002659.mp4
# /content/videos/normal/002660.mp4
# Processed 2660 normal videos.
# /content/videos/normal/002661.mp4
# /content/videos/normal/002662.mp4
# /content/videos/normal/002663.mp4
# /content/videos/normal/002664.mp4
# /content/videos/normal/002665.mp4
# /content/videos/normal/002666.mp4
# /content/videos/normal/002667.mp4
# /content/videos/normal/002668.mp4
# /content/videos/normal/002669.mp4
# /content/videos/normal/002670.mp4
# Processed 2670 normal videos.
# /content/videos/normal/002671.mp4
# /content/videos/normal/002672.mp4
# /content/videos/normal/002673.mp4
# /content/videos/normal/002674.mp4
# /content/videos/normal/002675.mp4
# /content/videos/normal/002676.mp4
# /content/videos/normal/002677.mp4
# /content/videos/normal/002678.mp4
# /content/videos/normal/002679.mp4
# /content/videos/normal/002680.mp4
# Processed 2680 normal videos.
# /content/videos/normal/002681.mp4
# /content/videos/normal/002682.mp4
# /content/videos/normal/002683.mp4
# /content/videos/normal/002684.mp4
# /content/videos/normal/002685.mp4
# /content/videos/normal/002686.mp4
# /content/videos/normal/002687.mp4
# /content/videos/normal/002688.mp4
# /content/videos/normal/002689.mp4
# /content/videos/normal/002690.mp4
# Processed 2690 normal videos.
# /content/videos/normal/002691.mp4
# /content/videos/normal/002692.mp4
# /content/videos/normal/002693.mp4
# /content/videos/normal/002694.mp4
# /content/videos/normal/002695.mp4
# /content/videos/normal/002696.mp4
# /content/videos/normal/002697.mp4
# /content/videos/normal/002698.mp4
# /content/videos/normal/002699.mp4
# /content/videos/normal/002700.mp4
# Processed 2700 normal videos.
# /content/videos/normal/002701.mp4
# /content/videos/normal/002702.mp4
# /content/videos/normal/002703.mp4
# /content/videos/normal/002704.mp4
# /content/videos/normal/002705.mp4
# /content/videos/normal/002706.mp4
# /content/videos/normal/002707.mp4
# /content/videos/normal/002708.mp4
# /content/videos/normal/002709.mp4
# /content/videos/normal/002710.mp4
# Processed 2710 normal videos.
# /content/videos/normal/002711.mp4
# /content/videos/normal/002712.mp4
# /content/videos/normal/002713.mp4
# /content/videos/normal/002714.mp4
# /content/videos/normal/002715.mp4
# /content/videos/normal/002716.mp4
# /content/videos/normal/002717.mp4
# /content/videos/normal/002718.mp4
# /content/videos/normal/002719.mp4
# /content/videos/normal/002720.mp4
# Processed 2720 normal videos.
# /content/videos/normal/002721.mp4
# /content/videos/normal/002722.mp4
# /content/videos/normal/002723.mp4
# /content/videos/normal/002724.mp4
# /content/videos/normal/002725.mp4
# /content/videos/normal/002726.mp4
# /content/videos/normal/002727.mp4
# /content/videos/normal/002728.mp4
# /content/videos/normal/002729.mp4
# /content/videos/normal/002730.mp4
# Processed 2730 normal videos.
# /content/videos/normal/002731.mp4
# /content/videos/normal/002732.mp4
# /content/videos/normal/002733.mp4
# /content/videos/normal/002734.mp4
# /content/videos/normal/002735.mp4
# /content/videos/normal/002736.mp4
# /content/videos/normal/002737.mp4
# /content/videos/normal/002738.mp4
# /content/videos/normal/002739.mp4
# /content/videos/normal/002740.mp4
# Processed 2740 normal videos.
# /content/videos/normal/002741.mp4
# /content/videos/normal/002742.mp4
# /content/videos/normal/002743.mp4
# /content/videos/normal/002744.mp4
# /content/videos/normal/002745.mp4
# /content/videos/normal/002746.mp4
# /content/videos/normal/002747.mp4
# /content/videos/normal/002748.mp4
# /content/videos/normal/002749.mp4
# /content/videos/normal/002750.mp4
# Processed 2750 normal videos.
# /content/videos/normal/002751.mp4
# /content/videos/normal/002752.mp4
# /content/videos/normal/002753.mp4
# /content/videos/normal/002754.mp4
# /content/videos/normal/002755.mp4
# /content/videos/normal/002756.mp4
# /content/videos/normal/002757.mp4
# /content/videos/normal/002758.mp4
# /content/videos/normal/002759.mp4
# /content/videos/normal/002760.mp4
# Processed 2760 normal videos.
# /content/videos/normal/002761.mp4
# /content/videos/normal/002762.mp4
# /content/videos/normal/002763.mp4
# /content/videos/normal/002764.mp4
# /content/videos/normal/002765.mp4
# /content/videos/normal/002766.mp4
# /content/videos/normal/002767.mp4
# /content/videos/normal/002768.mp4
# /content/videos/normal/002769.mp4
# /content/videos/normal/002770.mp4
# Processed 2770 normal videos.
# /content/videos/normal/002771.mp4
# /content/videos/normal/002772.mp4
# /content/videos/normal/002773.mp4
# /content/videos/normal/002774.mp4
# /content/videos/normal/002775.mp4
# /content/videos/normal/002776.mp4
# /content/videos/normal/002777.mp4
# /content/videos/normal/002778.mp4
# /content/videos/normal/002779.mp4
# /content/videos/normal/002780.mp4
# Processed 2780 normal videos.
# /content/videos/normal/002781.mp4
# /content/videos/normal/002782.mp4
# /content/videos/normal/002783.mp4
# /content/videos/normal/002784.mp4
# /content/videos/normal/002785.mp4
# /content/videos/normal/002786.mp4
# /content/videos/normal/002787.mp4
# /content/videos/normal/002788.mp4
# /content/videos/normal/002789.mp4
# /content/videos/normal/002790.mp4
# Processed 2790 normal videos.
# /content/videos/normal/002791.mp4
# /content/videos/normal/002792.mp4
# /content/videos/normal/002793.mp4
# /content/videos/normal/002794.mp4
# /content/videos/normal/002795.mp4
# /content/videos/normal/002796.mp4
# /content/videos/normal/002797.mp4
# /content/videos/normal/002798.mp4
# /content/videos/normal/002799.mp4
# /content/videos/normal/002800.mp4
# Processed 2800 normal videos.
# /content/videos/normal/002801.mp4
# /content/videos/normal/002802.mp4
# /content/videos/normal/002803.mp4
# /content/videos/normal/002804.mp4
# /content/videos/normal/002805.mp4
# /content/videos/normal/002806.mp4
# /content/videos/normal/002807.mp4
# /content/videos/normal/002808.mp4
# /content/videos/normal/002809.mp4
# /content/videos/normal/002810.mp4
# Processed 2810 normal videos.
# /content/videos/normal/002811.mp4
# /content/videos/normal/002812.mp4
# /content/videos/normal/002813.mp4
# /content/videos/normal/002814.mp4
# /content/videos/normal/002815.mp4
# /content/videos/normal/002816.mp4
# /content/videos/normal/002817.mp4
# /content/videos/normal/002818.mp4
# /content/videos/normal/002819.mp4
# /content/videos/normal/002820.mp4
# Processed 2820 normal videos.
# /content/videos/normal/002821.mp4
# /content/videos/normal/002822.mp4
# /content/videos/normal/002823.mp4
# /content/videos/normal/002824.mp4
# /content/videos/normal/002825.mp4
# /content/videos/normal/002826.mp4
# /content/videos/normal/002827.mp4
# /content/videos/normal/002828.mp4
# /content/videos/normal/002829.mp4
# /content/videos/normal/002830.mp4
# Processed 2830 normal videos.
# /content/videos/normal/002831.mp4
# /content/videos/normal/002832.mp4
# /content/videos/normal/002833.mp4
# /content/videos/normal/002834.mp4
# /content/videos/normal/002835.mp4
# /content/videos/normal/002836.mp4
# /content/videos/normal/002837.mp4
# /content/videos/normal/002838.mp4
# /content/videos/normal/002839.mp4
# /content/videos/normal/002840.mp4
# Processed 2840 normal videos.
# /content/videos/normal/002841.mp4
# /content/videos/normal/002842.mp4
# /content/videos/normal/002843.mp4
# /content/videos/normal/002844.mp4
# /content/videos/normal/002845.mp4
# /content/videos/normal/002846.mp4
# /content/videos/normal/002847.mp4
# /content/videos/normal/002848.mp4
# /content/videos/normal/002849.mp4
# /content/videos/normal/002850.mp4
# Processed 2850 normal videos.
# /content/videos/normal/002851.mp4
# /content/videos/normal/002852.mp4
# /content/videos/normal/002853.mp4
# /content/videos/normal/002854.mp4
# /content/videos/normal/002855.mp4
# /content/videos/normal/002856.mp4
# /content/videos/normal/002857.mp4
# /content/videos/normal/002858.mp4
# /content/videos/normal/002859.mp4
# /content/videos/normal/002860.mp4
# Processed 2860 normal videos.
# /content/videos/normal/002861.mp4
# /content/videos/normal/002862.mp4
# /content/videos/normal/002863.mp4
# /content/videos/normal/002864.mp4
# /content/videos/normal/002865.mp4
# /content/videos/normal/002866.mp4
# /content/videos/normal/002867.mp4
# /content/videos/normal/002868.mp4
# /content/videos/normal/002869.mp4
# /content/videos/normal/002870.mp4
# Processed 2870 normal videos.
# /content/videos/normal/002871.mp4
# /content/videos/normal/002872.mp4
# /content/videos/normal/002873.mp4
# /content/videos/normal/002874.mp4
# /content/videos/normal/002875.mp4
# /content/videos/normal/002876.mp4
# /content/videos/normal/002877.mp4
# /content/videos/normal/002878.mp4
# /content/videos/normal/002879.mp4
# /content/videos/normal/002880.mp4
# Processed 2880 normal videos.
# /content/videos/normal/002881.mp4
# /content/videos/normal/002882.mp4
# /content/videos/normal/002883.mp4
# /content/videos/normal/002884.mp4
# /content/videos/normal/002885.mp4
# /content/videos/normal/002886.mp4
# /content/videos/normal/002887.mp4
# /content/videos/normal/002888.mp4
# /content/videos/normal/002889.mp4
# /content/videos/normal/002890.mp4
# Processed 2890 normal videos.
# /content/videos/normal/002891.mp4
# /content/videos/normal/002892.mp4
# /content/videos/normal/002893.mp4
# /content/videos/normal/002894.mp4
# /content/videos/normal/002895.mp4
# /content/videos/normal/002896.mp4
# /content/videos/normal/002897.mp4
# /content/videos/normal/002898.mp4
# /content/videos/normal/002899.mp4
# /content/videos/normal/002900.mp4
# Processed 2900 normal videos.
# /content/videos/normal/002901.mp4
# /content/videos/normal/002902.mp4
# /content/videos/normal/002903.mp4
# /content/videos/normal/002904.mp4
# /content/videos/normal/002905.mp4
# /content/videos/normal/002906.mp4
# /content/videos/normal/002907.mp4
# /content/videos/normal/002908.mp4
# /content/videos/normal/002909.mp4
# /content/videos/normal/002910.mp4
# Processed 2910 normal videos.
# /content/videos/normal/002911.mp4
# /content/videos/normal/002912.mp4
# /content/videos/normal/002913.mp4
# /content/videos/normal/002914.mp4
# /content/videos/normal/002915.mp4
# /content/videos/normal/002916.mp4
# /content/videos/normal/002917.mp4
# /content/videos/normal/002918.mp4
# /content/videos/normal/002919.mp4
# /content/videos/normal/002920.mp4
# Processed 2920 normal videos.
# /content/videos/normal/002921.mp4
# /content/videos/normal/002922.mp4
# /content/videos/normal/002923.mp4
# /content/videos/normal/002924.mp4
# /content/videos/normal/002925.mp4
# /content/videos/normal/002926.mp4
# /content/videos/normal/002927.mp4
# /content/videos/normal/002928.mp4
# /content/videos/normal/002929.mp4
# /content/videos/normal/002930.mp4
# Processed 2930 normal videos.
# /content/videos/normal/002931.mp4
# /content/videos/normal/002932.mp4
# /content/videos/normal/002933.mp4
# /content/videos/normal/002934.mp4
# /content/videos/normal/002935.mp4
# /content/videos/normal/002936.mp4
# /content/videos/normal/002937.mp4
# /content/videos/normal/002938.mp4
# /content/videos/normal/002939.mp4
# /content/videos/normal/002940.mp4
# Processed 2940 normal videos.
# /content/videos/normal/002941.mp4
# /content/videos/normal/002942.mp4
# /content/videos/normal/002943.mp4
# /content/videos/normal/002944.mp4
# /content/videos/normal/002945.mp4
# /content/videos/normal/002946.mp4
# /content/videos/normal/002947.mp4
# /content/videos/normal/002948.mp4
# /content/videos/normal/002949.mp4
# /content/videos/normal/002950.mp4
# Processed 2950 normal videos.
# /content/videos/normal/002951.mp4
# /content/videos/normal/002952.mp4
# /content/videos/normal/002953.mp4
# /content/videos/normal/002954.mp4
# /content/videos/normal/002955.mp4
# /content/videos/normal/002956.mp4
# /content/videos/normal/002957.mp4
# /content/videos/normal/002958.mp4
# /content/videos/normal/002959.mp4
# /content/videos/normal/002960.mp4
# Processed 2960 normal videos.
# /content/videos/normal/002961.mp4
# /content/videos/normal/002962.mp4
# /content/videos/normal/002963.mp4
# /content/videos/normal/002964.mp4
# /content/videos/normal/002965.mp4
# /content/videos/normal/002966.mp4
# /content/videos/normal/002967.mp4
# /content/videos/normal/002968.mp4
# /content/videos/normal/002969.mp4
# /content/videos/normal/002970.mp4
# Processed 2970 normal videos.
# /content/videos/normal/002971.mp4
# /content/videos/normal/002972.mp4
# /content/videos/normal/002973.mp4
# /content/videos/normal/002974.mp4
# /content/videos/normal/002975.mp4
# /content/videos/normal/002976.mp4
# /content/videos/normal/002977.mp4
# /content/videos/normal/002978.mp4
# /content/videos/normal/002979.mp4
# /content/videos/normal/002980.mp4
# Processed 2980 normal videos.
# /content/videos/normal/002981.mp4
# /content/videos/normal/002982.mp4
# /content/videos/normal/002983.mp4
# /content/videos/normal/002984.mp4
# /content/videos/normal/002985.mp4
# /content/videos/normal/002986.mp4
# /content/videos/normal/002987.mp4
# /content/videos/normal/002988.mp4
# /content/videos/normal/002989.mp4
# /content/videos/normal/002990.mp4
# Processed 2990 normal videos.
# /content/videos/normal/002991.mp4
# /content/videos/normal/002992.mp4
# /content/videos/normal/002993.mp4
# /content/videos/normal/002994.mp4
# /content/videos/normal/002995.mp4
# /content/videos/normal/002996.mp4
# /content/videos/normal/002997.mp4
# /content/videos/normal/002998.mp4
# /content/videos/normal/002999.mp4
# /content/videos/normal/003000.mp4
# Processed 3000 normal videos.

# %%
egocentric_videos = filter_egocentric_videos("/content/Crash-1500.txt")
selected_videos = random.sample(egocentric_videos, 250)

for i, video in enumerate(egocentric_videos):
    video_name = video["vidname"]
    video_path = f"/content/videos/car_crash/{video_name}.mp4"
    start_frame, end_frame = get_frames_before_accident(video_path, video["binlabels"])
    frames_file_path = f"/content/video_frames/crash_{video_name}_frames.npz"
    np.savez_compressed(frames_file_path,
                        frames=extract_frames(video_path, first_frame=start_frame, last_frame=end_frame),
                        label=1)
    if (i+1) % 10 == 0 and i > 0:
        print(f"Processed {i+1} car crash videos.")

# %%
# @title Default title text
# Process ego-invovlve car crash videos
egocentric_videos = filter_egocentric_videos("/content/Crash-1500.txt")
#for i in range(len(egocentric_videos)):
for i in range(101, 151):
  video = egocentric_videos[i]
  video_name = video["vidname"]
  video_path = f"/content/videos/car_crash/{video_name}.mp4";
  start_frame, end_frame = get_frames_before_accident(video_path, video["binlabels"])
  frames_file_path = f"/content/video_frames/crash_{video_name}_frames.npz"
  np.savez_compressed(frames_file_path,
                      frames=extract_frames(video_path, first_frame=start_frame, last_frame=end_frame),
                      label = 1)
  if (i+1) % 10 == 0 and i > 0:
    print(f"Processed {i+1} car crash videos.")

# %%
import shutil
shutil.make_archive('video_frames', 'zip', '/content/video_frames')
# from google.colab import files
# files.download('video_frames.zip')

# %%
# @title Visualizing frames
egocentric_videos = filter_egocentric_videos("/content/Crash-1500.txt")
video = egocentric_videos[0]
video_name = video["vidname"]
video_path = f"/content/videos/car_crash/{video_name}.mp4";
start_frame, end_frame = get_frames_before_accident(video_path, video["binlabels"])

frames = []
frame_count = 0
cap = cv2.VideoCapture(video_path)
cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
while frame_count < 30:
  ret, frame = cap.read()
  frame = frame[..., ::-1]
  frames.append(frame)
  frame_count += 1
cap.release()

plt.figure(figsize=(10, 10))
for i in range(min(30, len(frames))):
    plt.subplot(5, 6, i + 1)
    plt.imshow(frames[i])
    plt.axis('off')
plt.show()

frames = np.load('/content/video_frames/crash_000001_frames.npz')['frames']
plt.figure(figsize=(10, 10))
for i in range(min(30, len(frames))):
    plt.subplot(5, 6, i + 1)
    plt.imshow(frames[i])
    plt.axis('off')
plt.show()

# %% [markdown]
# # **Train Test Spilt Data**

# %%
# !unzip /content/video_frames.zip -d /content/video_frames
# Out:
# unzip:  cannot find or open /content/video_frames.zip, /content/video_frames.zip.zip or /content/video_frames.zip.ZIP.

# %%
import gc
gc.collect()

# %reset -f

# %%
import torch
import numpy as np
from torch.utils.data import Dataset, DataLoader
import glob
from sklearn.model_selection import train_test_split
import zipfile
import os

class CarCrashDataset(Dataset):
    def __init__(self, file_paths):
        """
        Args:
            file_paths (list of str): Each path is the file path to a .npz file with frames and label.
        """
        self.file_paths = file_paths

    def __len__(self):
        return len(self.file_paths)

    def __getitem__(self, idx):
        data = np.load(self.file_paths[idx])
        frames = torch.tensor(data['frames'], dtype=torch.float32).permute(0, 3, 1, 2)  # Shape (30, C, H, W)
        label = torch.tensor(data['label'], dtype=torch.float32)
        return frames, label

file_paths = glob.glob('/content/video_frames/*.npz')
print(f"Number of .npz files found: {len(file_paths)}")

positive_files = [f for f in file_paths if np.load(f)['label'] == 1]
negative_files = [f for f in file_paths if np.load(f)['label'] == 0]

train_pos, temp_pos = train_test_split(positive_files, test_size=0.3, random_state=42)
val_pos, eval_pos = train_test_split(temp_pos, test_size=0.5, random_state=42)

train_neg, temp_neg = train_test_split(negative_files, test_size=0.3, random_state=42)
val_neg, eval_neg = train_test_split(temp_neg, test_size=0.5, random_state=42)

X_train = train_pos + train_neg
X_val = val_pos + val_neg
X_eval = eval_pos + eval_neg

np.random.shuffle(X_train)
np.random.shuffle(X_val)
np.random.shuffle(X_eval)

train_dataset = CarCrashDataset(X_train)
val_dataset = CarCrashDataset(X_val)
eval_dataset = CarCrashDataset(X_eval)

print(f"Train dataset length: {len(train_dataset)}")
print(f"Validation dataset length: {len(val_dataset)}")
print(f"Evaluation dataset length: {len(eval_dataset)}")

def count_labels(dataset):
    positive_count = 0
    negative_count = 0
    for _, label in dataset:
        if label.item() == 1:
            positive_count += 1
        else:
            negative_count += 1
    return positive_count, negative_count

train_positive, train_negative = count_labels(train_dataset)
val_positive, val_negative = count_labels(val_dataset)
eval_positive, eval_negative = count_labels(eval_dataset)
print(f"Train set: Positive = {train_positive}, Negative = {train_negative}")
print(f"Validation set: Positive = {val_positive}, Negative = {val_negative}")
print(f"Evaluation set: Positive = {eval_positive}, Negative = {eval_negative}")

def data_loader(params):
    train_loader = DataLoader(train_dataset, batch_size=params["batch_size"], shuffle=True, drop_last=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=params["batch_size"], shuffle=False, drop_last=False, num_workers=0)
    eval_loader = DataLoader(eval_dataset, batch_size=params["batch_size"], shuffle=False, drop_last=True, num_workers=0)

    return train_loader, val_loader, eval_loader

def save_dataset_as_zip(dataset, dataset_name, destination_folder='/content/zipped_datasets'):
    """
    Zips the files in the dataset and saves them as a single zip file.

    Args:
        dataset (Dataset): Dataset object containing file paths to be zipped.
        dataset_name (str): Name of the zip file to be created (e.g., "train", "val", "eval").
        destination_folder (str): Folder where the zip files will be stored.
    """
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    zip_path = os.path.join(destination_folder, f"{dataset_name}.zip")

    with zipfile.ZipFile(zip_path, 'w') as zipf:
        for file_path, _ in dataset:
            file_name = os.path.basename(file_path)
            zipf.write(file_path, arcname=file_name)

    print(f"{dataset_name}.zip created at {zip_path}")

# # Saving each dataset as a zip file
# save_dataset_as_zip(train_dataset, "train_dataset")
# save_dataset_as_zip(val_dataset, "val_dataset")
# save_dataset_as_zip(eval_dataset, "eval_dataset")
# Out:
# Number of .npz files found: 3801
# Train dataset length: 2660
# Validation dataset length: 570
# Evaluation dataset length: 571
# Train set: Positive = 560, Negative = 2100
# Validation set: Positive = 120, Negative = 450
# Evaluation set: Positive = 121, Negative = 450

# %% [markdown]
# # **Model**

# %% [markdown]
# Import Model Libraries

# %% [markdown]
# Model Definition

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import numpy as np
import gc

class CRNN(nn.Module):
    def __init__(self, input_shape):
        super(CRNN, self).__init__()

        self.dropout_lstm = nn.Dropout(p=0.2)
        self.dropout_fc = nn.Dropout(p=0.3)

        self.mobilenetv2 = models.mobilenet_v2(pretrained=True).features

        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.lstm1 = nn.LSTM(input_size=1280, hidden_size=128, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=128, hidden_size=64, batch_first=True)

        self.fc = nn.Linear(64, 1)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        batch_size, sequence_length, channels, height, width = x.size()

        cnn_features = []

        for t in range(sequence_length):
            frame_features = self.mobilenetv2(x[:, t, :, :, :])
            frame_features = self.global_avg_pool(frame_features)
            frame_features = frame_features.view(batch_size, -1)
            cnn_features.append(frame_features)

        cnn_features = torch.stack(cnn_features, dim=1)

        lstm_out, _ = self.lstm1(cnn_features)
        lstm_out = self.dropout_lstm(lstm_out)

        lstm_out, _ = self.lstm2(lstm_out)
        lstm_out = self.dropout_lstm(lstm_out)

        output = self.fc(lstm_out[:, -1, :])
        output = self.dropout_fc(output)

        output = self.sigmoid(output)

        return output

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
from sklearn.metrics import confusion_matrix
from torch.optim.lr_scheduler import ReduceLROnPlateau

class EarlyStopping:
    def __init__(self, patience=5, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                print("Early stopping triggered.")
                self.early_stop = True


def train_model(model, params, train_loader, val_loader):
    epochs = params['epochs']
    optimizer = torch.optim.Adam(model.parameters(), lr=params['lr'])
    pos_weight = torch.tensor([4.5]).to(device)
    criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
    # criterion = nn.BCELoss()
    early_stopping = EarlyStopping(patience=5, min_delta=0.001)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.7, patience=5)

    best_val_loss = float('inf')
    best_weights = None
    accumulation_steps = params.get('accumulation_steps', 1)

    for epoch in range(epochs):
        # Training step
        model.train()
        running_loss = 0.0

        for i, (frames, labels) in enumerate(train_loader):
            frames, labels = frames.to(device), labels.to(device)
            if len(labels.shape) == 1:
                labels = labels.view(-1, 1)

            optimizer.zero_grad()
            outputs = model(frames)
            loss = criterion(outputs, labels)
            loss = loss / accumulation_steps
            loss.backward()

            running_loss += loss.item()
            if (i + 1) % accumulation_steps == 0:
                optimizer.step()
                optimizer.zero_grad()

        print(f"Epoch {epoch + 1}/{epochs}, Loss: {running_loss / len(train_loader):.4f}")

        # Validation step
        model.eval()
        val_loss = 0.0
        all_labels = []
        all_preds = []

        with torch.no_grad():
            for frames, labels in val_loader:
                frames, labels = frames.to(device), labels.to(device)
                outputs = torch.sigmoid(model(frames))
                val_loss += criterion(outputs.squeeze(), labels.view(-1)).item()

                preds = (outputs > 0.5).float()
                all_labels.extend(labels.cpu().numpy())
                all_preds.extend(preds.cpu().numpy())

        val_loss /= len(val_loader)
        scheduler.step(val_loss)
        print(f"Epoch {epoch + 1}/{epochs}, Validation Loss: {val_loss:.4f}")

        tn, fp, fn, tp = confusion_matrix(all_labels, all_preds).ravel()
        false_positive_rate = fp / (fp + tn) if (fp + tn) > 0 else 0
        false_negative_rate = fn / (fn + tp) if (fn + tp) > 0 else 0

        print(f"False Positives: {fp}, False Negatives: {fn}")
        print(f"False Positive Rate: {false_positive_rate:.4f}, False Negative Rate: {false_negative_rate:.4f}")

        mlflow.log_metric("validation_loss", val_loss, step=epoch)
        # mlflow.log_metric("false_positives", fp, step=epoch)
        # mlflow.log_metric("false_negatives", fn, step=epoch)
        # mlflow.log_metric("false_positive_rate", false_positive_rate, step=epoch)
        # mlflow.log_metric("false_negative_rate", false_negative_rate, step=epoch)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_weights = model.state_dict()

        early_stopping(val_loss)
        if early_stopping.early_stop:
            print("Stopping training early...")
            break

    torch.save(best_weights, "best_model_weights.pth")
    mlflow.log_artifact("best_model_weights.pth")
    os.remove("best_model_weights.pth")

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import numpy as np

def evaluate_model(model, eval_loader, params):
    model.eval()
    correct = 0
    total = 0
    total_loss = 0.0
    total_samples = 0

    all_labels = []
    all_predictions = []

    criterion = nn.BCELoss()

    with torch.no_grad():
        for frames, labels in eval_loader:
            frames, labels = frames.to(device), labels.to(device)

            outputs = model(frames)
            predicted = (outputs > 0.5).float()
            total += labels.size(0)
            correct += (predicted.squeeze() == labels).sum().item()

            outputs = outputs.view(-1)
            loss = criterion(outputs, labels.view(-1))
            total_loss += loss.item() * labels.size(0)
            total_samples += labels.size(0)

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())

    avg_loss = total_loss / total_samples
    accuracy = correct / total
    precision = precision_score(all_labels, all_predictions, zero_division=0)
    recall = recall_score(all_labels, all_predictions, zero_division=0)
    f1 = f1_score(all_labels, all_predictions, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(all_labels, all_predictions).ravel()

    true_positives_count = np.sum(np.array(all_labels) == 1)
    true_negatives_count = np.sum(np.array(all_labels) == 0)
    predicted_positives_count = np.sum(np.array(all_predictions) == 1)
    predicted_negatives_count = np.sum(np.array(all_predictions) == 0)

    # print(f'Average Loss: {avg_loss:.4f}')
    # print(f'Accuracy: {accuracy:.4f}')
    # print(f'Confusion Matrix:')
    # print(f'True Negatives: {tn}, False Positives: {fp}')
    # print(f'False Negatives: {fn}, True Positives: {tp}')
    # print(f'Total Positive Labels: {true_positives_count}, Total Negative Labels: {true_negatives_count}')
    # print(f'Total Positive Predictions: {predicted_positives_count}, Total Negative Predictions: {predicted_negatives_count}')

    return avg_loss, accuracy, precision, recall, f1, tn, fp, fn, tp

# %%
def train_eval_model(params, model):
    # with mlflow.start_run(nested=False):
        model.to(device)
        train_loader, val_loader, eval_loader = data_loader(params)

        for param_name, param_value in params.items():
            mlflow.log_param(param_name, param_value)

        train_model(model, params, train_loader, val_loader)
        torch.cuda.empty_cache()
        gc.collect()
        avg_loss, accuracy, precision, recall, f1, tn, fp, fn, tp = evaluate_model(model, eval_loader, params)
        torch.cuda.empty_cache()
        gc.collect()

        mlflow.log_metric("average_loss", avg_loss)
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("f1_score", f1)
        mlflow.log_metric("tn", tn)
        mlflow.log_metric("fp", fp)
        mlflow.log_metric("fn", fn)
        mlflow.log_metric("tp", tp)
        return {'loss': avg_loss, 'status': STATUS_OK, 'model': model}

def objective(params):
    torch.cuda.empty_cache()
    gc.collect()
    if mlflow.active_run() is not None:
        print("Ending previous active run")
        mlflow.end_run()

    try:
        print("Starting new MLflow run")
        with mlflow.start_run():
            mlflow.set_tag("mlflow.runName", f"(weight=4.5, dropout=0.3, epoch=30) Trial with params: {params}")

            for param_name, param_value in params.items():
                mlflow.log_param(param_name, param_value)

            results = train_eval_model(params, CRNN(input_shape=(30, 128, 128, 3)).to(device))
            torch.cuda.empty_cache()
            gc.collect()

    finally:
        print("Ensuring run ends")
        mlflow.end_run()
        torch.cuda.empty_cache()
        gc.collect()

    return results

# %%
# Hyperparameters sweeping
import os
import pickle
from hyperopt import fmin, tpe, Trials
from hyperopt import STATUS_OK
from google.colab import files
import numpy as np
from hyperopt import hp
import mlflow

os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'
space = {
    "epochs": hp.choice("epochs", [30]),
    "batch_size": hp.choice("batch_size", [4]),
    "lr": hp.loguniform("lr", np.log(1e-5), np.log(1e-4)),
    "accumulation_steps": 4,
}

trials_file = 'trials.pkl'

if os.path.exists(trials_file):
    with open(trials_file, 'rb') as f:
        trials = pickle.load(f)
else:
    trials = Trials()

max_evals = 2
mlflow.set_experiment("/datasize-500")

with mlflow.start_run():
    best = fmin(
        fn=objective,
        space=space,
        algo=tpe.suggest,
        max_evals=max_evals + len(trials.trials),
        trials=trials
    )

    best_run = sorted(trials.results, key=lambda x: x["loss"])[0]

    mlflow.log_params(best)
    # mlflow.tensorflow.log_model(best_run["model"], "model", signature=signature)
    # mlflow.pytorch.log_model(best_run["model"], "model")

    print(f"Best parameters: {best}")
    print(f"Best eval rmse: {best_run['loss']}")

    with open(trials_file, 'wb') as f:
      pickle.dump(trials, f)

    files.download(trials_file)

best_trial = trials.best_trial
print("Best Trial:", best_trial)
# Out:
# Ending previous active run
#   0%|          | 0/2 [00:00<?, ?trial/s, best loss=?]
# 2024/11/13 22:12:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run dashing-boar-32 at: https://community.cloud.databricks.com/ml/experiments/3052994282681228/runs/adc50efc7e82486abc8662ce175c5f1c.
#
# 2024/11/13 22:12:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://community.cloud.databricks.com/ml/experiments/3052994282681228.
# Starting new MLflow run
#   0%|          | 0/2 [00:00<?, ?trial/s, best loss=?]
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
#
#   0%|          | 0.00/13.6M [00:00<?, ?B/s]
#
#  56%|#####6    | 7.62M/13.6M [00:00<00:00, 79.8MB/s]
#
# 100%|##########| 13.6M/13.6M [00:00<00:00, 95.3MB/s]
# 2024/11/13 22:12:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run (weight=4.5, dropout=0.3, epoch=30) Trial with params: {'accumulation_steps': 4, 'batch_size': 4, 'epochs': 30, 'lr': 6.155511193231504e-05} at: https://community.cloud.databricks.com/ml/experiments/3052994282681228/runs/24d022e1282d409796563df8603fb44d.
#
# 2024/11/13 22:12:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://community.cloud.databricks.com/ml/experiments/3052994282681228.
# Ensuring run ends
#   0%|          | 0/2 [00:05<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2d68f7a67241> in <cell line: 30>()
#      29
#      30 with mlflow.start_run():
# ---> 31     best = fmin(
#      32         fn=objective,
#      33         space=space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# /usr/local/lib/python3.10/dist-packages/hyperopt/base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-10-cfd46d68a3ec> in objective(params)
#      39                 mlflow.log_param(param_name, param_value)
#      40
# ---> 41             results = train_eval_model(params, CRNN(input_shape=(30, 128, 128, 3)).to(device))
#      42             torch.cuda.empty_cache()
#      43             gc.collect()
#
# <ipython-input-10-cfd46d68a3ec> in train_eval_model(params, model)
#       7             mlflow.log_param(param_name, param_value)
#       8
# ----> 9         train_model(model, params, train_loader, val_loader)
#      10         torch.cuda.empty_cache()
#      11         gc.collect()
#
# <ipython-input-8-877f2182fb86> in train_model(model, params, train_loader, val_loader)
#      48
#      49             optimizer.zero_grad()
# ---> 50             outputs = model(frames)
#      51             loss = criterion(outputs, labels)
#      52             loss = loss / accumulation_steps
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# <ipython-input-7-6c7f28e3678e> in forward(self, x)
#      29
#      30         for t in range(sequence_length):
# ---> 31             frame_features = self.mobilenetv2(x[:, t, :, :, :])
#      32             frame_features = self.global_avg_pool(frame_features)
#      33             frame_features = frame_features.view(batch_size, -1)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:

# %%
# Train model with predefined params
import os
import pickle
from hyperopt import fmin, tpe, Trials
from hyperopt import STATUS_OK
from google.colab import files
import numpy as np
from hyperopt import hp
import mlflow
import gc

mlflow.set_experiment("/datasize-500")
params = {
    "epochs": 40,
    "batch_size": 16,
    "lr": 9.007553054088038e-05,
    "accumulation_steps": 4,
}

with mlflow.start_run():
  mlflow.set_tag("mlflow.runName", f"unbalanced data (with scheduler) without weighted loss Trial with params: {params}")
  for param_name, param_value in params.items():
    mlflow.log_param(param_name, param_value)
  train_eval_model(params, CRNN(input_shape=(30, 128, 128, 3)))

# %%
mlflow.end_run()
